# %% [markdown]
# # Diffraction shift correction with py4DSTEM
#
# The code in this notebook determines the shifts of the diffraction pattern in a 4D-STEM dataset associated with the scanning of the electron beam, then corrects those shifts, outputting a new 4D data hypercube in which the shifts have been removed.
#
# The general procedure is as follows:
# 1. Get vacuum probe
# 2. Get shifts
#     * Get raw shifts
#     * Fit shifts
# 3. Correct the shifts

# %%
import py4DSTEM

import numpy as np
import matplotlib.pyplot as plt

from scipy.ndimage.morphology import binary_dilation as binary_dilation
from scipy.ndimage.filters import gaussian_filter
from scipy.optimize import curve_fit

from time import time

# %%
fp = "/Users/Ben/Work/NCEM/Projects/py4DSTEM/sample_data/20180905_FePO4_unlithiated/Stack2_60x60+30nmss_spot 8_0p05s_CL=600_alpha=0p48_300kV_bin4.h5"
dc = py4DSTEM.readwrite.read_data(fp)
# Out:
# Reading file /Users/Ben/Work/NCEM/Projects/py4DSTEM/sample_data/20180905_FePO4_unlithiated/Stack2_60x60+30nmss_spot 8_0p05s_CL=600_alpha=0p48_300kV_bin4.h5...
#
# /Users/Ben/Work/NCEM/Projects/py4DSTEM/sample_data/20180905_FePO4_unlithiated/Stack2_60x60+30nmss_spot 8_0p05s_CL=600_alpha=0p48_300kV_bin4.h5 is a py4DSTEM HDF5 file.  Reading...

# %%
dc.data4D = np.roll(dc.data4D,-2,1) # Correct for acquisition wrap-around error

# %% [markdown]
# ## 1. Get the vacuum probe
#
# The aim here is to create a convolution kernel in the shape of the unscattered electron beam, which can then be used to identify the Bragg disks in each diffraction pattern of the datacube.  We procede as follows:
#
# * Get average vacuum probe
#     * Select an ROI over (nearly) vacuum
#     * Find shifts of DPs within ROI relative to one reference DP
#     * Register and average all DPs in ROI
# * Create vacuum probe kernel
#     * Mask probe outside of central disk
#     * Get probe CoM and size
#     * Normalize probe to integrate to 1
#     * Subtract normalized 2D gaussian to get kernel integrating to 0
#     * Center kernel in Fourier space (i.e. at corners of array)

# %%
# ROI

xmin,xmax=45,55
ymin,ymax=5,15

im_ROI_sel = np.average(dc.data4D,axis=(2,3))
im_ROI_sel[xmin:xmax,ymin:ymax] = 0
fig,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(12,8))
ax1.matshow(np.average(dc.data4D,axis=(2,3)),cmap='gray')
ax2.matshow(im_ROI_sel,cmap='gray')
ax3.matshow(np.average(dc.data4D,axis=(2,3))[xmin:xmax,ymin:ymax,],cmap='gray')
plt.show()

# %%
# Average DP, unshifted

DP_ave_unshifted = np.average(dc.data4D[xmin:xmax,ymin:ymax],axis=(0,1))

fig,ax=plt.subplots()
ax.matshow(DP_ave_unshifted,cmap='gray')
plt.show()

# %%
# Get average shifted diffraction pattern

ref_DP = dc.data4D[xmin,ymin,:,:]

for n in range(1,(xmax-xmin)*(ymax-ymin)):
    i = xmin + n%(xmax-xmin)
    j = ymin + int(n/(xmax-xmin))
    curr_DP = dc.data4D[i,j,:,:]
    
    xshift,yshift = py4DSTEM.process.utils.get_shift(ref_DP, curr_DP)
    curr_DP_shifted = py4DSTEM.process.utils.get_shifted_ar(curr_DP,xshift,yshift)
    ref_DP = ref_DP*(n-1)/n + curr_DP_shifted/n

# %%
# Get (initial) center of mass
# Show shifted, averaged DP

xCoM_init,yCoM_init = py4DSTEM.process.utils.get_CoM(ref_DP)

fig,(ax1,ax2)=plt.subplots(1,2)
ax1.matshow(ref_DP,cmap='gray')
ax2.matshow(ref_DP[int(xCoM_init)-50:int(xCoM_init)+50,int(yCoM_init)-50:int(yCoM_init)+50])
plt.show()

# %%
# Compare shifted to unshifted ave DPs

xCoM_unshifted,yCoM_unshifted = py4DSTEM.process.utils.get_CoM(DP_ave_unshifted)

fig,(ax1,ax2)=plt.subplots(1,2)
ax1.matshow(ref_DP[int(xCoM_init)-50:int(xCoM_init)+50,int(yCoM_init)-50:int(yCoM_init)+50])
ax2.matshow(DP_ave_unshifted[int(xCoM_unshifted)-50:int(xCoM_unshifted)+50,int(yCoM_unshifted)-50:int(yCoM_unshifted)+50])
plt.show()

# %%
# Mask probe outside of central disk

mask_thresh = 0.2
mask_expansion = 12

ry,rx = np.meshgrid(dc.data4D.shape[1],dc.data4D.shape[0])
mask = ref_DP > np.max(ref_DP)*mask_thresh
mask = binary_dilation(mask,iterations=mask_expansion)

#maskDist = 0.5 + 0.5*erf(maskShift + (bwdist(~maskRound) - bwdist(bwmorph(maskRound,'dilate',1))) / (0.5*maskWidth));

probe_template = ref_DP*mask

# %%
# Get CoM
# Compare to CoM without mask

xCoM,yCoM = py4DSTEM.process.utils.get_CoM(probe_template)

fig,(ax1,ax2)=plt.subplots(1,2)
ax1.matshow(probe_template[int(xCoM)-50:int(xCoM)+50,int(yCoM)-50:int(yCoM)+50])
ax2.matshow(ref_DP[int(xCoM_init)-50:int(xCoM_init)+50,int(yCoM_init)-50:int(yCoM_init)+50])
plt.show()

print("Mask alters CoM by {} pixels.".format(np.sqrt((yCoM-yCoM_init)**2+(xCoM-xCoM_init)**2)))
# Out:
# Mask alters CoM by 0.3101400088527627 pixels.

# %%
# Get probe size

r2 = (rx-xCoM)**2 + (ry-yCoM)**2
rstd = np.sum(r2*probe_template*mask) / np.sum(probe_template)

# %%
# Normalize probe to one
# Subtract off gaussian, to yield a kernel which integrates to zero
sigma_probe_scale = 5

probe_template_norm = probe_template/np.sum(probe_template)
subtr_gaussian = probe_template_norm - np.exp(-r2 / (2*rstd*sigma_probe_scale**2))
subtr_gaussian = subtr_gaussian/np.sum(subtr_gaussian)
probe_kernel = probe_template_norm - subtr_gaussian

print("Probe kernel sums to {}.".format(np.sum(probe_kernel)))
# Out:
# Probe kernel sums to -3.3306690738754696e-16.

# %%
# Shift probe kernel to center, then to corners
probe_kernel = py4DSTEM.process.utils.get_shifted_ar(probe_kernel,-xCoM,-yCoM)

# %%
fig,ax=plt.subplots()
ax.matshow(probe_kernel,cmap='gray')
plt.show()

# %% [markdown]
# ## 2. Get the diffraction shifts
#
# In this step the relative shift of each diffraction pattern is determined, as follows:
#
# * For one diffraction pattern, get the Bragg disk positions of unscattered beam.
#     * Convolve with the probe kernel
#     * Get the positions and strengths of all bragg disks by identifying local maxima
# * For all DPs, get the positions of unscattered beam.
#     * Loop over all DPs, get all Bragg disk positions
#     * Get the average deconvolution
#     * Get average central beam position, from brightest peak of average deconvolution
#     * Get the central beam for each DP, as closest peak to average central beam position
# * Fit diffraction shifts
#     * Fit plane or 2d parabaloid to unscattered beam positions

# %% [markdown]
# ### 2a. Single diffraction pattern
#
# * For one diffraction pattern, get the Bragg disk positions of unscattered beam.
#     * Convolve with the probe kernel
#     * Get the positions and strengths of all bragg disks by identifying local maxima

# %%
# Pick a test diffraction pattern
Ri,Rj = 30,30
DP = dc.data4D[Ri,Rj,:,:]

fig,ax=plt.subplots(figsize=(8,8))
ax.matshow(DP)
plt.show()

# %%
# Cross correlation

corrPower = 1  # Correlation type, in [0,1]. 0=phase correlation, 1=cross correlation

cc = py4DSTEM.process.utils.get_cross_correlation(DP,probe_kernel,corrPower)

fig,ax = plt.subplots(figsize=(8,8))
ax.matshow(np.abs(cc))
plt.show()

# %%
# Test different hybrid correlations

ccs = []
probe_kernel_FT = np.conj(np.fft.fft2(probe_kernel))
for corrPower in np.linspace(0,1,5):
    cc = py4DSTEM.process.utils.get_cross_correlation_fk(DP,probe_kernel_FT,corrPower)
    ccs.append(cc)

fig,axs = plt.subplots(1,5,figsize=(24,48))
for i in range(len(ccs)):
    axs[i].matshow(np.abs(ccs[i]))
plt.show()

# %%
# Select hybrid correlation coefficient

corrPower = 0.75  # Correlation type, in [0,1]. 0=phase correlation, 1=cross correlation

cc = py4DSTEM.process.utils.get_cross_correlation(DP,probe_kernel,corrPower)

fig,ax = plt.subplots(figsize=(8,8))
ax.matshow(np.abs(cc))
plt.show()

# %%
# Apply small gaussian smoothing filter

sigma_gaussianFilter = 2

cc = np.maximum(cc,0)
cc = gaussian_filter(cc, sigma_gaussianFilter)

# %%
# Show cross correlation and log(cc)

fig,(ax1,ax2) = plt.subplots(1,2,figsize=(12,12))
ax1.matshow(cc)
ax2.matshow(np.maximum(cc,0)**0.25)
plt.show()

# %%
# Get maximal points

max_points = py4DSTEM.process.utils.get_maximal_points(cc)

# %%
# Show max_points with cross correlation

fig,(ax1,ax2) = plt.subplots(1,2,figsize=(12,12))
ax1.matshow(cc)
ax2.matshow(max_points)
plt.show()

# %%
# Zoom in

xc,yc = py4DSTEM.process.utils.get_CoM(cc)

fig,(ax1,ax2)=plt.subplots(1,2,figsize=(12,12))
ax1.matshow(cc[int(xc)-50:int(xc)+50,int(yc)-50:int(yc)+50])
ax2.matshow(max_points[int(xc)-50:int(xc)+50,int(yc)-50:int(yc)+50])
plt.show()

# %%
edge_boundary = 20

max_points[:edge_boundary,:]=False
max_points[-edge_boundary:,:]=False
max_points[:,:edge_boundary]=False
max_points[:,-edge_boundary:]=False

# %%
# Show
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(12,12))
ax1.matshow(cc)
ax2.matshow(max_points)
plt.show()

# %%
# Make point_list with structured array datatype

point_list_type=np.dtype([('rx',float),('ry',float),('qx',float),('qy',float),('intensity',float)])
point_list = np.array([],dtype=point_list_type)

max_point_indices_x, max_point_indices_y = np.nonzero(max_points)
point_intensities = cc[max_point_indices_x,max_point_indices_y]

length = len(point_intensities)
for i in range(length):
    new_point = (Ri,Rj,max_point_indices_x[i],max_point_indices_y[i],point_intensities[i])
    point_list = np.append(point_list, np.array(new_point,dtype=point_list_type))

# %%
# Order point list, keep only up to maxNumPeaks

maxNumPeaks = 45

numPeaks = min(maxNumPeaks,length)
point_list = np.sort(point_list,order='intensity')[::-1]
point_list = point_list[:numPeaks]

# %%
fig,ax=plt.subplots(figsize=(12,12))
ax.matshow(DP)
ax.scatter(point_list['qy'],point_list['qx'],color='r')
plt.show()

# %%
# Remove peaks that are too close together

minPeakSpacing = 32

r2 = minPeakSpacing**2
deletePeaks = np.zeros(numPeaks,dtype=bool)
for i in range(numPeaks):
    if deletePeaks[i] == False:
        tooClose = ( (point_list['qx']-point_list['qx'][i])**2 + \
                  (point_list['qy']-point_list['qy'][i])**2 ) < r2
        tooClose[:i+1] = False
        deletePeaks[tooClose] = True
point_list = np.delete(point_list,deletePeaks.nonzero()[0])

# %%
fig,ax=plt.subplots(figsize=(12,12))
ax.matshow(DP)
ax.scatter(point_list['qy'],point_list['qx'],color='r')
plt.show()

# %% [markdown]
# ### 2b. Get diffraction shifts for all DPs
#
# * For all DPs, get the positions of unscattered beam.
#     * Loop over all DPs, get all Bragg disk positions
#     * Get the average deconvolution
#     * Get average central beam position, from brightest peak of average deconvolution
#     * Get the central beam for each DP, using closest peak to average central beam position

# %%
# Loop over all DP's, getting all Bragg disk positions

corrPower = 0.75
sigma_gaussianFilter = 2
edge_boundary = 20
maxNumPeaks = 45
minPeakSpacing = 32

point_list_type=np.dtype([('rx',float),('ry',float),('qx',float),('qy',float),('intensity',float)])
Bragg_peak_point_list = np.array([],dtype=point_list_type)

t0=time()
probe_kernel_FT = np.conj(np.fft.fft2(probe_kernel))
for Ri in range(dc.R_Nx):
    for Rj in range(dc.R_Ny):
        print("Analyzing scan position {},{}".format(Ri,Rj))

        # Get diffraction pattern
        DP = dc.data4D[Ri,Rj,:,:]
        
        # Cross correlation     
        cc = py4DSTEM.process.utils.get_cross_correlation_fk(DP,probe_kernel_FT,corrPower)

        # Gaussian smoothing
        cc = np.maximum(cc,0)
        cc = gaussian_filter(cc, sigma_gaussianFilter)
        
        # Get maximal points
        max_points = py4DSTEM.process.utils.get_maximal_points(cc)
        
        # Remove points at edges
        max_points[:edge_boundary,:]=False
        max_points[-edge_boundary:,:]=False
        max_points[:,:edge_boundary]=False
        max_points[:,-edge_boundary:]=False    
       
        # Make point_list with structured array datatype ('rx','ry','qx','qy','intensity')
        point_list = np.array([],dtype=point_list_type)

        max_point_indices_x, max_point_indices_y = np.nonzero(max_points)
        point_intensities = cc[max_point_indices_x,max_point_indices_y]

        length = len(point_intensities)
        for i in range(length):
            new_point = (Ri,Rj,max_point_indices_x[i],max_point_indices_y[i],point_intensities[i])
            point_list = np.append(point_list, np.array(new_point,dtype=point_list_type))
        
        # Order point list, keep only up to maxNumPeaks
        numPeaks = min(maxNumPeaks,length)
        point_list = np.sort(point_list,order='intensity')[::-1]
        point_list = point_list[:numPeaks]        
        
        # Remove peaks that are too close together
        r2 = minPeakSpacing**2
        deletePeaks = np.zeros(numPeaks,dtype=bool)
        for i in range(numPeaks):
            if deletePeaks[i] == False:
                tooClose = ( (point_list['qx']-point_list['qx'][i])**2 + \
                          (point_list['qy']-point_list['qy'][i])**2 ) < r2
                tooClose[:i+1] = False
                deletePeaks[tooClose] = True
        point_list = np.delete(point_list,deletePeaks.nonzero()[0])
    
        # Add current point list to running list
        Bragg_peak_point_list = np.append(Bragg_peak_point_list, point_list)
            
t=time()-t0
print("Finished in {}h {}m {}s".format(int(t/3600),int(t/60),int(t%60)))
# Out:
# Analyzing scan position 0,0
# Analyzing scan position 0,1
# Analyzing scan position 0,2
# Analyzing scan position 0,3
# Analyzing scan position 0,4
# Analyzing scan position 0,5
# Analyzing scan position 0,6
# Analyzing scan position 0,7
# Analyzing scan position 0,8
# Analyzing scan position 0,9
# Analyzing scan position 0,10
# Analyzing scan position 0,11
# Analyzing scan position 0,12
# Analyzing scan position 0,13
# Analyzing scan position 0,14
# Analyzing scan position 0,15
# Analyzing scan position 0,16
# Analyzing scan position 0,17
# Analyzing scan position 0,18
# Analyzing scan position 0,19
# Analyzing scan position 0,20
# Analyzing scan position 0,21
# Analyzing scan position 0,22
# Analyzing scan position 0,23
# Analyzing scan position 0,24
# Analyzing scan position 0,25
# Analyzing scan position 0,26
# Analyzing scan position 0,27
# Analyzing scan position 0,28
# Analyzing scan position 0,29
# Analyzing scan position 0,30
# Analyzing scan position 0,31
# Analyzing scan position 0,32
# Analyzing scan position 0,33
# Analyzing scan position 0,34
# Analyzing scan position 0,35
# Analyzing scan position 0,36
# Analyzing scan position 0,37
# Analyzing scan position 0,38
# Analyzing scan position 0,39
# Analyzing scan position 0,40
# Analyzing scan position 0,41
# Analyzing scan position 0,42
# Analyzing scan position 0,43
# Analyzing scan position 0,44
# Analyzing scan position 0,45
# Analyzing scan position 0,46
# Analyzing scan position 0,47
# Analyzing scan position 0,48
# Analyzing scan position 0,49
# Analyzing scan position 0,50
# Analyzing scan position 0,51
# Analyzing scan position 0,52
# Analyzing scan position 0,53
# Analyzing scan position 0,54
# Analyzing scan position 0,55
# Analyzing scan position 0,56
# Analyzing scan position 0,57
# Analyzing scan position 0,58
# Analyzing scan position 0,59
# Analyzing scan position 1,0
# Analyzing scan position 1,1
# Analyzing scan position 1,2
# Analyzing scan position 1,3
# Analyzing scan position 1,4
# Analyzing scan position 1,5
# Analyzing scan position 1,6
# Analyzing scan position 1,7
# Analyzing scan position 1,8
# Analyzing scan position 1,9
# Analyzing scan position 1,10
# Analyzing scan position 1,11
# Analyzing scan position 1,12
# Analyzing scan position 1,13
# Analyzing scan position 1,14
# Analyzing scan position 1,15
# Analyzing scan position 1,16
# Analyzing scan position 1,17
# Analyzing scan position 1,18
# Analyzing scan position 1,19
# Analyzing scan position 1,20
# Analyzing scan position 1,21
# Analyzing scan position 1,22
# Analyzing scan position 1,23
# Analyzing scan position 1,24
# Analyzing scan position 1,25
# Analyzing scan position 1,26
# Analyzing scan position 1,27
# Analyzing scan position 1,28
# Analyzing scan position 1,29
# Analyzing scan position 1,30
# Analyzing scan position 1,31
# Analyzing scan position 1,32
# Analyzing scan position 1,33
# Analyzing scan position 1,34
# Analyzing scan position 1,35
# Analyzing scan position 1,36
# Analyzing scan position 1,37
# Analyzing scan position 1,38
# Analyzing scan position 1,39
# Analyzing scan position 1,40
# Analyzing scan position 1,41
# Analyzing scan position 1,42
# Analyzing scan position 1,43
# Analyzing scan position 1,44
# Analyzing scan position 1,45
# Analyzing scan position 1,46
# Analyzing scan position 1,47
# Analyzing scan position 1,48
# Analyzing scan position 1,49
# Analyzing scan position 1,50
# Analyzing scan position 1,51
# Analyzing scan position 1,52
# Analyzing scan position 1,53
# Analyzing scan position 1,54
# Analyzing scan position 1,55
# Analyzing scan position 1,56
# Analyzing scan position 1,57
# Analyzing scan position 1,58
# Analyzing scan position 1,59
# Analyzing scan position 2,0
# Analyzing scan position 2,1
# Analyzing scan position 2,2
# Analyzing scan position 2,3
# Analyzing scan position 2,4
# Analyzing scan position 2,5
# Analyzing scan position 2,6
# Analyzing scan position 2,7
# Analyzing scan position 2,8
# Analyzing scan position 2,9
# Analyzing scan position 2,10
# Analyzing scan position 2,11
# Analyzing scan position 2,12
# Analyzing scan position 2,13
# Analyzing scan position 2,14
# Analyzing scan position 2,15
# Analyzing scan position 2,16
# Analyzing scan position 2,17
# Analyzing scan position 2,18
# Analyzing scan position 2,19
# Analyzing scan position 2,20
# Analyzing scan position 2,21
# Analyzing scan position 2,22
# Analyzing scan position 2,23
# Analyzing scan position 2,24
# Analyzing scan position 2,25
# Analyzing scan position 2,26
# Analyzing scan position 2,27
# Analyzing scan position 2,28
# Analyzing scan position 2,29
# Analyzing scan position 2,30
# Analyzing scan position 2,31
# Analyzing scan position 2,32
# Analyzing scan position 2,33
# Analyzing scan position 2,34
# Analyzing scan position 2,35
# Analyzing scan position 2,36
# Analyzing scan position 2,37
# Analyzing scan position 2,38
# Analyzing scan position 2,39
# Analyzing scan position 2,40
# Analyzing scan position 2,41
# Analyzing scan position 2,42
# Analyzing scan position 2,43
# Analyzing scan position 2,44
# Analyzing scan position 2,45
# Analyzing scan position 2,46
# Analyzing scan position 2,47
# Analyzing scan position 2,48
# Analyzing scan position 2,49
# Analyzing scan position 2,50
# Analyzing scan position 2,51
# Analyzing scan position 2,52
# Analyzing scan position 2,53
# Analyzing scan position 2,54
# Analyzing scan position 2,55
# Analyzing scan position 2,56
# Analyzing scan position 2,57
# Analyzing scan position 2,58
# Analyzing scan position 2,59
# Analyzing scan position 3,0
# Analyzing scan position 3,1
# Analyzing scan position 3,2
# Analyzing scan position 3,3
# Analyzing scan position 3,4
# Analyzing scan position 3,5
# Analyzing scan position 3,6
# Analyzing scan position 3,7
# Analyzing scan position 3,8
# Analyzing scan position 3,9
# Analyzing scan position 3,10
# Analyzing scan position 3,11
# Analyzing scan position 3,12
# Analyzing scan position 3,13
# Analyzing scan position 3,14
# Analyzing scan position 3,15
# Analyzing scan position 3,16
# Analyzing scan position 3,17
# Analyzing scan position 3,18
# Analyzing scan position 3,19
# Analyzing scan position 3,20
# Analyzing scan position 3,21
# Analyzing scan position 3,22
# Analyzing scan position 3,23
# Analyzing scan position 3,24
# Analyzing scan position 3,25
# Analyzing scan position 3,26
# Analyzing scan position 3,27
# Analyzing scan position 3,28
# Analyzing scan position 3,29
# Analyzing scan position 3,30
# Analyzing scan position 3,31
# Analyzing scan position 3,32
# Analyzing scan position 3,33
# Analyzing scan position 3,34
# Analyzing scan position 3,35
# Analyzing scan position 3,36
# Analyzing scan position 3,37
# Analyzing scan position 3,38
# Analyzing scan position 3,39
# Analyzing scan position 3,40
# Analyzing scan position 3,41
# Analyzing scan position 3,42
# Analyzing scan position 3,43
# Analyzing scan position 3,44
# Analyzing scan position 3,45
# Analyzing scan position 3,46
# Analyzing scan position 3,47
# Analyzing scan position 3,48
# Analyzing scan position 3,49
# Analyzing scan position 3,50
# Analyzing scan position 3,51
# Analyzing scan position 3,52
# Analyzing scan position 3,53
# Analyzing scan position 3,54
# Analyzing scan position 3,55
# Analyzing scan position 3,56
# Analyzing scan position 3,57
# Analyzing scan position 3,58
# Analyzing scan position 3,59
# Analyzing scan position 4,0
# Analyzing scan position 4,1
# Analyzing scan position 4,2
# Analyzing scan position 4,3
# Analyzing scan position 4,4
# Analyzing scan position 4,5
# Analyzing scan position 4,6
# Analyzing scan position 4,7
# Analyzing scan position 4,8
# Analyzing scan position 4,9
# Analyzing scan position 4,10
# Analyzing scan position 4,11
# Analyzing scan position 4,12
# Analyzing scan position 4,13
# Analyzing scan position 4,14
# Analyzing scan position 4,15
# Analyzing scan position 4,16
# Analyzing scan position 4,17
# Analyzing scan position 4,18
# Analyzing scan position 4,19
# Analyzing scan position 4,20
# Analyzing scan position 4,21
# Analyzing scan position 4,22
# Analyzing scan position 4,23
# Analyzing scan position 4,24
# Analyzing scan position 4,25
# Analyzing scan position 4,26
# Analyzing scan position 4,27
# Analyzing scan position 4,28
# Analyzing scan position 4,29
# Analyzing scan position 4,30
# Analyzing scan position 4,31
# Analyzing scan position 4,32
# Analyzing scan position 4,33
# Analyzing scan position 4,34
# Analyzing scan position 4,35
# Analyzing scan position 4,36
# Analyzing scan position 4,37
# Analyzing scan position 4,38
# Analyzing scan position 4,39
# Analyzing scan position 4,40
# Analyzing scan position 4,41
# Analyzing scan position 4,42
# Analyzing scan position 4,43
# Analyzing scan position 4,44
# Analyzing scan position 4,45
# Analyzing scan position 4,46
# Analyzing scan position 4,47
# Analyzing scan position 4,48
# Analyzing scan position 4,49
# Analyzing scan position 4,50
# Analyzing scan position 4,51
# Analyzing scan position 4,52
# Analyzing scan position 4,53
# Analyzing scan position 4,54
# Analyzing scan position 4,55
# Analyzing scan position 4,56
# Analyzing scan position 4,57
# Analyzing scan position 4,58
# Analyzing scan position 4,59
# Analyzing scan position 5,0
# Analyzing scan position 5,1
# Analyzing scan position 5,2
# Analyzing scan position 5,3
# Analyzing scan position 5,4
# Analyzing scan position 5,5
# Analyzing scan position 5,6
# Analyzing scan position 5,7
# Analyzing scan position 5,8
# Analyzing scan position 5,9
# Analyzing scan position 5,10
# Analyzing scan position 5,11
# Analyzing scan position 5,12
# Analyzing scan position 5,13
# Analyzing scan position 5,14
# Analyzing scan position 5,15
# Analyzing scan position 5,16
# Analyzing scan position 5,17
# Analyzing scan position 5,18
# Analyzing scan position 5,19
# Analyzing scan position 5,20
# Analyzing scan position 5,21
# Analyzing scan position 5,22
# Analyzing scan position 5,23
# Analyzing scan position 5,24
# Analyzing scan position 5,25
# Analyzing scan position 5,26
# Analyzing scan position 5,27
# Analyzing scan position 5,28
# Analyzing scan position 5,29
# Analyzing scan position 5,30
# Analyzing scan position 5,31
# Analyzing scan position 5,32
# Analyzing scan position 5,33
# Analyzing scan position 5,34
# Analyzing scan position 5,35
# Analyzing scan position 5,36
# Analyzing scan position 5,37
# Analyzing scan position 5,38
# Analyzing scan position 5,39
# Analyzing scan position 5,40
# Analyzing scan position 5,41
# Analyzing scan position 5,42
# Analyzing scan position 5,43
# Analyzing scan position 5,44
# Analyzing scan position 5,45
# Analyzing scan position 5,46
# Analyzing scan position 5,47
# Analyzing scan position 5,48
# Analyzing scan position 5,49
# Analyzing scan position 5,50
# Analyzing scan position 5,51
# Analyzing scan position 5,52
# Analyzing scan position 5,53
# Analyzing scan position 5,54
# Analyzing scan position 5,55
# Analyzing scan position 5,56
# Analyzing scan position 5,57
# Analyzing scan position 5,58
# Analyzing scan position 5,59
# Analyzing scan position 6,0
# Analyzing scan position 6,1
# Analyzing scan position 6,2
# Analyzing scan position 6,3
# Analyzing scan position 6,4
# Analyzing scan position 6,5
# Analyzing scan position 6,6
# Analyzing scan position 6,7
# Analyzing scan position 6,8
# Analyzing scan position 6,9
# Analyzing scan position 6,10
# Analyzing scan position 6,11
# Analyzing scan position 6,12
# Analyzing scan position 6,13
# Analyzing scan position 6,14
# Analyzing scan position 6,15
# Analyzing scan position 6,16
# Analyzing scan position 6,17
# Analyzing scan position 6,18
# Analyzing scan position 6,19
# Analyzing scan position 6,20
# Analyzing scan position 6,21
# Analyzing scan position 6,22
# Analyzing scan position 6,23
# Analyzing scan position 6,24
# Analyzing scan position 6,25
# Analyzing scan position 6,26
# Analyzing scan position 6,27
# Analyzing scan position 6,28
# Analyzing scan position 6,29
# Analyzing scan position 6,30
# Analyzing scan position 6,31
# Analyzing scan position 6,32
# Analyzing scan position 6,33
# Analyzing scan position 6,34
# Analyzing scan position 6,35
# Analyzing scan position 6,36
# Analyzing scan position 6,37
# Analyzing scan position 6,38
# Analyzing scan position 6,39
# Analyzing scan position 6,40
# Analyzing scan position 6,41
# Analyzing scan position 6,42
# Analyzing scan position 6,43
# Analyzing scan position 6,44
# Analyzing scan position 6,45
# Analyzing scan position 6,46
# Analyzing scan position 6,47
# Analyzing scan position 6,48
# Analyzing scan position 6,49
# Analyzing scan position 6,50
# Analyzing scan position 6,51
# Analyzing scan position 6,52
# Analyzing scan position 6,53
# Analyzing scan position 6,54
# Analyzing scan position 6,55
# Analyzing scan position 6,56
# Analyzing scan position 6,57
# Analyzing scan position 6,58
# Analyzing scan position 6,59
# Analyzing scan position 7,0
# Analyzing scan position 7,1
# Analyzing scan position 7,2
# Analyzing scan position 7,3
# Analyzing scan position 7,4
# Analyzing scan position 7,5
# Analyzing scan position 7,6
# Analyzing scan position 7,7
# Analyzing scan position 7,8
# Analyzing scan position 7,9
# Analyzing scan position 7,10
# Analyzing scan position 7,11
# Analyzing scan position 7,12
# Analyzing scan position 7,13
# Analyzing scan position 7,14
# Analyzing scan position 7,15
# Analyzing scan position 7,16
# Analyzing scan position 7,17
# Analyzing scan position 7,18
# Analyzing scan position 7,19
# Analyzing scan position 7,20
# Analyzing scan position 7,21
# Analyzing scan position 7,22
# Analyzing scan position 7,23
# Analyzing scan position 7,24
# Analyzing scan position 7,25
# Analyzing scan position 7,26
# Analyzing scan position 7,27
# Analyzing scan position 7,28
# Analyzing scan position 7,29
# Analyzing scan position 7,30
# Analyzing scan position 7,31
# Analyzing scan position 7,32
# Analyzing scan position 7,33
# Analyzing scan position 7,34
# Analyzing scan position 7,35
# Analyzing scan position 7,36
# Analyzing scan position 7,37
# Analyzing scan position 7,38
# Analyzing scan position 7,39
# Analyzing scan position 7,40
# Analyzing scan position 7,41
# Analyzing scan position 7,42
# Analyzing scan position 7,43
# Analyzing scan position 7,44
# Analyzing scan position 7,45
# Analyzing scan position 7,46
# Analyzing scan position 7,47
# Analyzing scan position 7,48
# Analyzing scan position 7,49
# Analyzing scan position 7,50
# Analyzing scan position 7,51
# Analyzing scan position 7,52
# Analyzing scan position 7,53
# Analyzing scan position 7,54
# Analyzing scan position 7,55
# Analyzing scan position 7,56
# Analyzing scan position 7,57
# Analyzing scan position 7,58
# Analyzing scan position 7,59
# Analyzing scan position 8,0
# Analyzing scan position 8,1
# Analyzing scan position 8,2
# Analyzing scan position 8,3
# Analyzing scan position 8,4
# Analyzing scan position 8,5
# Analyzing scan position 8,6
# Analyzing scan position 8,7
# Analyzing scan position 8,8
# Analyzing scan position 8,9
# Analyzing scan position 8,10
# Analyzing scan position 8,11
# Analyzing scan position 8,12
# Analyzing scan position 8,13
# Analyzing scan position 8,14
# Analyzing scan position 8,15
# Analyzing scan position 8,16
# Analyzing scan position 8,17
# Analyzing scan position 8,18
# Analyzing scan position 8,19
# Analyzing scan position 8,20
# Analyzing scan position 8,21
# Analyzing scan position 8,22
# Analyzing scan position 8,23
# Analyzing scan position 8,24
# Analyzing scan position 8,25
# Analyzing scan position 8,26
# Analyzing scan position 8,27
# Analyzing scan position 8,28
# Analyzing scan position 8,29
# Analyzing scan position 8,30
# Analyzing scan position 8,31
# Analyzing scan position 8,32
# Analyzing scan position 8,33
# Analyzing scan position 8,34
# Analyzing scan position 8,35
# Analyzing scan position 8,36
# Analyzing scan position 8,37
# Analyzing scan position 8,38
# Analyzing scan position 8,39
# Analyzing scan position 8,40
# Analyzing scan position 8,41
# Analyzing scan position 8,42
# Analyzing scan position 8,43
# Analyzing scan position 8,44
# Analyzing scan position 8,45
# Analyzing scan position 8,46
# Analyzing scan position 8,47
# Analyzing scan position 8,48
# Analyzing scan position 8,49
# Analyzing scan position 8,50
# Analyzing scan position 8,51
# Analyzing scan position 8,52
# Analyzing scan position 8,53
# Analyzing scan position 8,54
# Analyzing scan position 8,55
# Analyzing scan position 8,56
# Analyzing scan position 8,57
# Analyzing scan position 8,58
# Analyzing scan position 8,59
# Analyzing scan position 9,0
# Analyzing scan position 9,1
# Analyzing scan position 9,2
# Analyzing scan position 9,3
# Analyzing scan position 9,4
# Analyzing scan position 9,5
# Analyzing scan position 9,6
# Analyzing scan position 9,7
# Analyzing scan position 9,8
# Analyzing scan position 9,9
# Analyzing scan position 9,10
# Analyzing scan position 9,11
# Analyzing scan position 9,12
# Analyzing scan position 9,13
# Analyzing scan position 9,14
# Analyzing scan position 9,15
# Analyzing scan position 9,16
# Analyzing scan position 9,17
# Analyzing scan position 9,18
# Analyzing scan position 9,19
# Analyzing scan position 9,20
# Analyzing scan position 9,21
# Analyzing scan position 9,22
# Analyzing scan position 9,23
# Analyzing scan position 9,24
# Analyzing scan position 9,25
# Analyzing scan position 9,26
# Analyzing scan position 9,27
# Analyzing scan position 9,28
# Analyzing scan position 9,29
# Analyzing scan position 9,30
# Analyzing scan position 9,31
# Analyzing scan position 9,32
# Analyzing scan position 9,33
# Analyzing scan position 9,34
# Analyzing scan position 9,35
# Analyzing scan position 9,36
# Analyzing scan position 9,37
# Analyzing scan position 9,38
# Analyzing scan position 9,39
# Analyzing scan position 9,40
# Analyzing scan position 9,41
# Analyzing scan position 9,42
# Analyzing scan position 9,43
# Analyzing scan position 9,44
# Analyzing scan position 9,45
# Analyzing scan position 9,46
# Analyzing scan position 9,47
# Analyzing scan position 9,48
# Analyzing scan position 9,49
# Analyzing scan position 9,50
# Analyzing scan position 9,51
# Analyzing scan position 9,52
# Analyzing scan position 9,53
# Analyzing scan position 9,54
# Analyzing scan position 9,55
# Analyzing scan position 9,56
# Analyzing scan position 9,57
# Analyzing scan position 9,58
# Analyzing scan position 9,59
# Analyzing scan position 10,0
# Analyzing scan position 10,1
# Analyzing scan position 10,2
# Analyzing scan position 10,3
# Analyzing scan position 10,4
# Analyzing scan position 10,5
# Analyzing scan position 10,6
# Analyzing scan position 10,7
# Analyzing scan position 10,8
# Analyzing scan position 10,9
# Analyzing scan position 10,10
# Analyzing scan position 10,11
# Analyzing scan position 10,12
# Analyzing scan position 10,13
# Analyzing scan position 10,14
# Analyzing scan position 10,15
# Analyzing scan position 10,16
# Analyzing scan position 10,17
# Analyzing scan position 10,18
# Analyzing scan position 10,19
# Analyzing scan position 10,20
# Analyzing scan position 10,21
# Analyzing scan position 10,22
# Analyzing scan position 10,23
# Analyzing scan position 10,24
# Analyzing scan position 10,25
# Analyzing scan position 10,26
# Analyzing scan position 10,27
# Analyzing scan position 10,28
# Analyzing scan position 10,29
# Analyzing scan position 10,30
# Analyzing scan position 10,31
# Analyzing scan position 10,32
# Analyzing scan position 10,33
# Analyzing scan position 10,34
# Analyzing scan position 10,35
# Analyzing scan position 10,36
# Analyzing scan position 10,37
# Analyzing scan position 10,38
# Analyzing scan position 10,39
# Analyzing scan position 10,40
# Analyzing scan position 10,41
# Analyzing scan position 10,42
# Analyzing scan position 10,43
# Analyzing scan position 10,44
# Analyzing scan position 10,45
# Analyzing scan position 10,46
# Analyzing scan position 10,47
# Analyzing scan position 10,48
# Analyzing scan position 10,49
# Analyzing scan position 10,50
# Analyzing scan position 10,51
# Analyzing scan position 10,52
# Analyzing scan position 10,53
# Analyzing scan position 10,54
# Analyzing scan position 10,55
# Analyzing scan position 10,56
# Analyzing scan position 10,57
# Analyzing scan position 10,58
# Analyzing scan position 10,59
# Analyzing scan position 11,0
# Analyzing scan position 11,1
# Analyzing scan position 11,2
# Analyzing scan position 11,3
# Analyzing scan position 11,4
# Analyzing scan position 11,5
# Analyzing scan position 11,6
# Analyzing scan position 11,7
# Analyzing scan position 11,8
# Analyzing scan position 11,9
# Analyzing scan position 11,10
# Analyzing scan position 11,11
# Analyzing scan position 11,12
# Analyzing scan position 11,13
# Analyzing scan position 11,14
# Analyzing scan position 11,15
# Analyzing scan position 11,16
# Analyzing scan position 11,17
# Analyzing scan position 11,18
# Analyzing scan position 11,19
# Analyzing scan position 11,20
# Analyzing scan position 11,21
# Analyzing scan position 11,22
# Analyzing scan position 11,23
# Analyzing scan position 11,24
# Analyzing scan position 11,25
# Analyzing scan position 11,26
# Analyzing scan position 11,27
# Analyzing scan position 11,28
# Analyzing scan position 11,29
# Analyzing scan position 11,30
# Analyzing scan position 11,31
# Analyzing scan position 11,32
# Analyzing scan position 11,33
# Analyzing scan position 11,34
# Analyzing scan position 11,35
# Analyzing scan position 11,36
# Analyzing scan position 11,37
# Analyzing scan position 11,38
# Analyzing scan position 11,39
# Analyzing scan position 11,40
# Analyzing scan position 11,41
# Analyzing scan position 11,42
# Analyzing scan position 11,43
# Analyzing scan position 11,44
# Analyzing scan position 11,45
# Analyzing scan position 11,46
# Analyzing scan position 11,47
# Analyzing scan position 11,48
# Analyzing scan position 11,49
# Analyzing scan position 11,50
# Analyzing scan position 11,51
# Analyzing scan position 11,52
# Analyzing scan position 11,53
# Analyzing scan position 11,54
# Analyzing scan position 11,55
# Analyzing scan position 11,56
# Analyzing scan position 11,57
# Analyzing scan position 11,58
# Analyzing scan position 11,59
# Analyzing scan position 12,0
# Analyzing scan position 12,1
# Analyzing scan position 12,2
# Analyzing scan position 12,3
# Analyzing scan position 12,4
# Analyzing scan position 12,5
# Analyzing scan position 12,6
# Analyzing scan position 12,7
# Analyzing scan position 12,8
# Analyzing scan position 12,9
# Analyzing scan position 12,10
# Analyzing scan position 12,11
# Analyzing scan position 12,12
# Analyzing scan position 12,13
# Analyzing scan position 12,14
# Analyzing scan position 12,15
# Analyzing scan position 12,16
# Analyzing scan position 12,17
# Analyzing scan position 12,18
# Analyzing scan position 12,19
# Analyzing scan position 12,20
# Analyzing scan position 12,21
# Analyzing scan position 12,22
# Analyzing scan position 12,23
# Analyzing scan position 12,24
# Analyzing scan position 12,25
# Analyzing scan position 12,26
# Analyzing scan position 12,27
# Analyzing scan position 12,28
# Analyzing scan position 12,29
# Analyzing scan position 12,30
# Analyzing scan position 12,31
# Analyzing scan position 12,32
# Analyzing scan position 12,33
# Analyzing scan position 12,34
# Analyzing scan position 12,35
# Analyzing scan position 12,36
# Analyzing scan position 12,37
# Analyzing scan position 12,38
# Analyzing scan position 12,39
# Analyzing scan position 12,40
# Analyzing scan position 12,41
# Analyzing scan position 12,42
# Analyzing scan position 12,43
# Analyzing scan position 12,44
# Analyzing scan position 12,45
# Analyzing scan position 12,46
# Analyzing scan position 12,47
# Analyzing scan position 12,48
# Analyzing scan position 12,49
# Analyzing scan position 12,50
# Analyzing scan position 12,51
# Analyzing scan position 12,52
# Analyzing scan position 12,53
# Analyzing scan position 12,54
# Analyzing scan position 12,55
# Analyzing scan position 12,56
# Analyzing scan position 12,57
# Analyzing scan position 12,58
# Analyzing scan position 12,59
# Analyzing scan position 13,0
# Analyzing scan position 13,1
# Analyzing scan position 13,2
# Analyzing scan position 13,3
# Analyzing scan position 13,4
# Analyzing scan position 13,5
# Analyzing scan position 13,6
# Analyzing scan position 13,7
# Analyzing scan position 13,8
# Analyzing scan position 13,9
# Analyzing scan position 13,10
# Analyzing scan position 13,11
# Analyzing scan position 13,12
# Analyzing scan position 13,13
# Analyzing scan position 13,14
# Analyzing scan position 13,15
# Analyzing scan position 13,16
# Analyzing scan position 13,17
# Analyzing scan position 13,18
# Analyzing scan position 13,19
# Analyzing scan position 13,20
# Analyzing scan position 13,21
# Analyzing scan position 13,22
# Analyzing scan position 13,23
# Analyzing scan position 13,24
# Analyzing scan position 13,25
# Analyzing scan position 13,26
# Analyzing scan position 13,27
# Analyzing scan position 13,28
# Analyzing scan position 13,29
# Analyzing scan position 13,30
# Analyzing scan position 13,31
# Analyzing scan position 13,32
# Analyzing scan position 13,33
# Analyzing scan position 13,34
# Analyzing scan position 13,35
# Analyzing scan position 13,36
# Analyzing scan position 13,37
# Analyzing scan position 13,38
# Analyzing scan position 13,39
# Analyzing scan position 13,40
# Analyzing scan position 13,41
# Analyzing scan position 13,42
# Analyzing scan position 13,43
# Analyzing scan position 13,44
# Analyzing scan position 13,45
# Analyzing scan position 13,46
# Analyzing scan position 13,47
# Analyzing scan position 13,48
# Analyzing scan position 13,49
# Analyzing scan position 13,50
# Analyzing scan position 13,51
# Analyzing scan position 13,52
# Analyzing scan position 13,53
# Analyzing scan position 13,54
# Analyzing scan position 13,55
# Analyzing scan position 13,56
# Analyzing scan position 13,57
# Analyzing scan position 13,58
# Analyzing scan position 13,59
# Analyzing scan position 14,0
# Analyzing scan position 14,1
# Analyzing scan position 14,2
# Analyzing scan position 14,3
# Analyzing scan position 14,4
# Analyzing scan position 14,5
# Analyzing scan position 14,6
# Analyzing scan position 14,7
# Analyzing scan position 14,8
# Analyzing scan position 14,9
# Analyzing scan position 14,10
# Analyzing scan position 14,11
# Analyzing scan position 14,12
# Analyzing scan position 14,13
# Analyzing scan position 14,14
# Analyzing scan position 14,15
# Analyzing scan position 14,16
# Analyzing scan position 14,17
# Analyzing scan position 14,18
# Analyzing scan position 14,19
# Analyzing scan position 14,20
# Analyzing scan position 14,21
# Analyzing scan position 14,22
# Analyzing scan position 14,23
# Analyzing scan position 14,24
# Analyzing scan position 14,25
# Analyzing scan position 14,26
# Analyzing scan position 14,27
# Analyzing scan position 14,28
# Analyzing scan position 14,29
# Analyzing scan position 14,30
# Analyzing scan position 14,31
# Analyzing scan position 14,32
# Analyzing scan position 14,33
# Analyzing scan position 14,34
# Analyzing scan position 14,35
# Analyzing scan position 14,36
# Analyzing scan position 14,37
# Analyzing scan position 14,38
# Analyzing scan position 14,39
# Analyzing scan position 14,40
# Analyzing scan position 14,41
# Analyzing scan position 14,42
# Analyzing scan position 14,43
# Analyzing scan position 14,44
# Analyzing scan position 14,45
# Analyzing scan position 14,46
# Analyzing scan position 14,47
# Analyzing scan position 14,48
# Analyzing scan position 14,49
# Analyzing scan position 14,50
# Analyzing scan position 14,51
# Analyzing scan position 14,52
# Analyzing scan position 14,53
# Analyzing scan position 14,54
# Analyzing scan position 14,55
# Analyzing scan position 14,56
# Analyzing scan position 14,57
# Analyzing scan position 14,58
# Analyzing scan position 14,59
# Analyzing scan position 15,0
# Analyzing scan position 15,1
# Analyzing scan position 15,2
# Analyzing scan position 15,3
# Analyzing scan position 15,4
# Analyzing scan position 15,5
# Analyzing scan position 15,6
# Analyzing scan position 15,7
# Analyzing scan position 15,8
# Analyzing scan position 15,9
# Analyzing scan position 15,10
# Analyzing scan position 15,11
# Analyzing scan position 15,12
# Analyzing scan position 15,13
# Analyzing scan position 15,14
# Analyzing scan position 15,15
# Analyzing scan position 15,16
# Analyzing scan position 15,17
# Analyzing scan position 15,18
# Analyzing scan position 15,19
# Analyzing scan position 15,20
# Analyzing scan position 15,21
# Analyzing scan position 15,22
# Analyzing scan position 15,23
# Analyzing scan position 15,24
# Analyzing scan position 15,25
# Analyzing scan position 15,26
# Analyzing scan position 15,27
# Analyzing scan position 15,28
# Analyzing scan position 15,29
# Analyzing scan position 15,30
# Analyzing scan position 15,31
# Analyzing scan position 15,32
# Analyzing scan position 15,33
# Analyzing scan position 15,34
# Analyzing scan position 15,35
# Analyzing scan position 15,36
# Analyzing scan position 15,37
# Analyzing scan position 15,38
# Analyzing scan position 15,39
# Analyzing scan position 15,40
# Analyzing scan position 15,41
# Analyzing scan position 15,42
# Analyzing scan position 15,43
# Analyzing scan position 15,44
# Analyzing scan position 15,45
# Analyzing scan position 15,46
# Analyzing scan position 15,47
# Analyzing scan position 15,48
# Analyzing scan position 15,49
# Analyzing scan position 15,50
# Analyzing scan position 15,51
# Analyzing scan position 15,52
# Analyzing scan position 15,53
# Analyzing scan position 15,54
# Analyzing scan position 15,55
# Analyzing scan position 15,56
# Analyzing scan position 15,57
# Analyzing scan position 15,58
# Analyzing scan position 15,59
# Analyzing scan position 16,0
# Analyzing scan position 16,1
# Analyzing scan position 16,2
# Analyzing scan position 16,3
# Analyzing scan position 16,4
# Analyzing scan position 16,5
# Analyzing scan position 16,6
# Analyzing scan position 16,7
# Analyzing scan position 16,8
# Analyzing scan position 16,9
# Analyzing scan position 16,10
# Analyzing scan position 16,11
# Analyzing scan position 16,12
# Analyzing scan position 16,13
# Analyzing scan position 16,14
# Analyzing scan position 16,15
# Analyzing scan position 16,16
# Analyzing scan position 16,17
# Analyzing scan position 16,18
# Analyzing scan position 16,19
# Analyzing scan position 16,20
# Analyzing scan position 16,21
# Analyzing scan position 16,22
# Analyzing scan position 16,23
# Analyzing scan position 16,24
# Analyzing scan position 16,25
# Analyzing scan position 16,26
# Analyzing scan position 16,27
# Analyzing scan position 16,28
# Analyzing scan position 16,29
# Analyzing scan position 16,30
# Analyzing scan position 16,31
# Analyzing scan position 16,32
# Analyzing scan position 16,33
# Analyzing scan position 16,34
# Analyzing scan position 16,35
# Analyzing scan position 16,36
# Analyzing scan position 16,37
# Analyzing scan position 16,38
# Analyzing scan position 16,39
# Analyzing scan position 16,40
# Analyzing scan position 16,41
# Analyzing scan position 16,42
# Analyzing scan position 16,43
# Analyzing scan position 16,44
# Analyzing scan position 16,45
# Analyzing scan position 16,46
# Analyzing scan position 16,47
# Analyzing scan position 16,48
# Analyzing scan position 16,49
# Analyzing scan position 16,50
# Analyzing scan position 16,51
# Analyzing scan position 16,52
# Analyzing scan position 16,53
# Analyzing scan position 16,54
# Analyzing scan position 16,55
# Analyzing scan position 16,56
# Analyzing scan position 16,57
# Analyzing scan position 16,58
# Analyzing scan position 16,59
# Analyzing scan position 17,0
# Analyzing scan position 17,1
# Analyzing scan position 17,2
# Analyzing scan position 17,3
# Analyzing scan position 17,4
# Analyzing scan position 17,5
# Analyzing scan position 17,6
# Analyzing scan position 17,7
# Analyzing scan position 17,8
# Analyzing scan position 17,9
# Analyzing scan position 17,10
# Analyzing scan position 17,11
# Analyzing scan position 17,12
# Analyzing scan position 17,13
# Analyzing scan position 17,14
# Analyzing scan position 17,15
# Analyzing scan position 17,16
# Analyzing scan position 17,17
# Analyzing scan position 17,18
# Analyzing scan position 17,19
# Analyzing scan position 17,20
# Analyzing scan position 17,21
# Analyzing scan position 17,22
# Analyzing scan position 17,23
# Analyzing scan position 17,24
# Analyzing scan position 17,25
# Analyzing scan position 17,26
# Analyzing scan position 17,27
# Analyzing scan position 17,28
# Analyzing scan position 17,29
# Analyzing scan position 17,30
# Analyzing scan position 17,31
# Analyzing scan position 17,32
# Analyzing scan position 17,33
# Analyzing scan position 17,34
# Analyzing scan position 17,35
# Analyzing scan position 17,36
# Analyzing scan position 17,37
# Analyzing scan position 17,38
# Analyzing scan position 17,39
# Analyzing scan position 17,40
# Analyzing scan position 17,41
# Analyzing scan position 17,42
# Analyzing scan position 17,43
# Analyzing scan position 17,44
# Analyzing scan position 17,45
# Analyzing scan position 17,46
# Analyzing scan position 17,47
# Analyzing scan position 17,48
# Analyzing scan position 17,49
# Analyzing scan position 17,50
# Analyzing scan position 17,51
# Analyzing scan position 17,52
# Analyzing scan position 17,53
# Analyzing scan position 17,54
# Analyzing scan position 17,55
# Analyzing scan position 17,56
# Analyzing scan position 17,57
# Analyzing scan position 17,58
# Analyzing scan position 17,59
# Analyzing scan position 18,0
# Analyzing scan position 18,1
# Analyzing scan position 18,2
# Analyzing scan position 18,3
# Analyzing scan position 18,4
# Analyzing scan position 18,5
# Analyzing scan position 18,6
# Analyzing scan position 18,7
# Analyzing scan position 18,8
# Analyzing scan position 18,9
# Analyzing scan position 18,10
# Analyzing scan position 18,11
# Analyzing scan position 18,12
# Analyzing scan position 18,13
# Analyzing scan position 18,14
# Analyzing scan position 18,15
# Analyzing scan position 18,16
# Analyzing scan position 18,17
# Analyzing scan position 18,18
# Analyzing scan position 18,19
# Analyzing scan position 18,20
# Analyzing scan position 18,21
# Analyzing scan position 18,22
# Analyzing scan position 18,23
# Analyzing scan position 18,24
# Analyzing scan position 18,25
# Analyzing scan position 18,26
# Analyzing scan position 18,27
# Analyzing scan position 18,28
# Analyzing scan position 18,29
# Analyzing scan position 18,30
# Analyzing scan position 18,31
# Analyzing scan position 18,32
# Analyzing scan position 18,33
# Analyzing scan position 18,34
# Analyzing scan position 18,35
# Analyzing scan position 18,36
# Analyzing scan position 18,37
# Analyzing scan position 18,38
# Analyzing scan position 18,39
# Analyzing scan position 18,40
# Analyzing scan position 18,41
# Analyzing scan position 18,42
# Analyzing scan position 18,43
# Analyzing scan position 18,44
# Analyzing scan position 18,45
# Analyzing scan position 18,46
# Analyzing scan position 18,47
# Analyzing scan position 18,48
# Analyzing scan position 18,49
# Analyzing scan position 18,50
# Analyzing scan position 18,51
# Analyzing scan position 18,52
# Analyzing scan position 18,53
# Analyzing scan position 18,54
# Analyzing scan position 18,55
# Analyzing scan position 18,56
# Analyzing scan position 18,57
# Analyzing scan position 18,58
# Analyzing scan position 18,59
# Analyzing scan position 19,0
# Analyzing scan position 19,1
# Analyzing scan position 19,2
# Analyzing scan position 19,3
# Analyzing scan position 19,4
# Analyzing scan position 19,5
# Analyzing scan position 19,6
# Analyzing scan position 19,7
# Analyzing scan position 19,8
# Analyzing scan position 19,9
# Analyzing scan position 19,10
# Analyzing scan position 19,11
# Analyzing scan position 19,12
# Analyzing scan position 19,13
# Analyzing scan position 19,14
# Analyzing scan position 19,15
# Analyzing scan position 19,16
# Analyzing scan position 19,17
# Analyzing scan position 19,18
# Analyzing scan position 19,19
# Analyzing scan position 19,20
# Analyzing scan position 19,21
# Analyzing scan position 19,22
# Analyzing scan position 19,23
# Analyzing scan position 19,24
# Analyzing scan position 19,25
# Analyzing scan position 19,26
# Analyzing scan position 19,27
# Analyzing scan position 19,28
# Analyzing scan position 19,29
# Analyzing scan position 19,30
# Analyzing scan position 19,31
# Analyzing scan position 19,32
# Analyzing scan position 19,33
# Analyzing scan position 19,34
# Analyzing scan position 19,35
# Analyzing scan position 19,36
# Analyzing scan position 19,37
# Analyzing scan position 19,38
# Analyzing scan position 19,39
# Analyzing scan position 19,40
# Analyzing scan position 19,41
# Analyzing scan position 19,42
# Analyzing scan position 19,43
# Analyzing scan position 19,44
# Analyzing scan position 19,45
# Analyzing scan position 19,46
# Analyzing scan position 19,47
# Analyzing scan position 19,48
# Analyzing scan position 19,49
# Analyzing scan position 19,50
# Analyzing scan position 19,51
# Analyzing scan position 19,52
# Analyzing scan position 19,53
# Analyzing scan position 19,54
# Analyzing scan position 19,55
# Analyzing scan position 19,56
# Analyzing scan position 19,57
# Analyzing scan position 19,58
# Analyzing scan position 19,59
# Analyzing scan position 20,0
# Analyzing scan position 20,1
# Analyzing scan position 20,2
# Analyzing scan position 20,3
# Analyzing scan position 20,4
# Analyzing scan position 20,5
# Analyzing scan position 20,6
# Analyzing scan position 20,7
# Analyzing scan position 20,8
# Analyzing scan position 20,9
# Analyzing scan position 20,10
# Analyzing scan position 20,11
# Analyzing scan position 20,12
# Analyzing scan position 20,13
# Analyzing scan position 20,14
# Analyzing scan position 20,15
# Analyzing scan position 20,16
# Analyzing scan position 20,17
# Analyzing scan position 20,18
# Analyzing scan position 20,19
# Analyzing scan position 20,20
# Analyzing scan position 20,21
# Analyzing scan position 20,22
# Analyzing scan position 20,23
# Analyzing scan position 20,24
# Analyzing scan position 20,25
# Analyzing scan position 20,26
# Analyzing scan position 20,27
# Analyzing scan position 20,28
# Analyzing scan position 20,29
# Analyzing scan position 20,30
# Analyzing scan position 20,31
# Analyzing scan position 20,32
# Analyzing scan position 20,33
# Analyzing scan position 20,34
# Analyzing scan position 20,35
# Analyzing scan position 20,36
# Analyzing scan position 20,37
# Analyzing scan position 20,38
# Analyzing scan position 20,39
# Analyzing scan position 20,40
# Analyzing scan position 20,41
# Analyzing scan position 20,42
# Analyzing scan position 20,43
# Analyzing scan position 20,44
# Analyzing scan position 20,45
# Analyzing scan position 20,46
# Analyzing scan position 20,47
# Analyzing scan position 20,48
# Analyzing scan position 20,49
# Analyzing scan position 20,50
# Analyzing scan position 20,51
# Analyzing scan position 20,52
# Analyzing scan position 20,53
# Analyzing scan position 20,54
# Analyzing scan position 20,55
# Analyzing scan position 20,56
# Analyzing scan position 20,57
# Analyzing scan position 20,58
# Analyzing scan position 20,59
# Analyzing scan position 21,0
# Analyzing scan position 21,1
# Analyzing scan position 21,2
# Analyzing scan position 21,3
# Analyzing scan position 21,4
# Analyzing scan position 21,5
# Analyzing scan position 21,6
# Analyzing scan position 21,7
# Analyzing scan position 21,8
# Analyzing scan position 21,9
# Analyzing scan position 21,10
# Analyzing scan position 21,11
# Analyzing scan position 21,12
# Analyzing scan position 21,13
# Analyzing scan position 21,14
# Analyzing scan position 21,15
# Analyzing scan position 21,16
# Analyzing scan position 21,17
# Analyzing scan position 21,18
# Analyzing scan position 21,19
# Analyzing scan position 21,20
# Analyzing scan position 21,21
# Analyzing scan position 21,22
# Analyzing scan position 21,23
# Analyzing scan position 21,24
# Analyzing scan position 21,25
# Analyzing scan position 21,26
# Analyzing scan position 21,27
# Analyzing scan position 21,28
# Analyzing scan position 21,29
# Analyzing scan position 21,30
# Analyzing scan position 21,31
# Analyzing scan position 21,32
# Analyzing scan position 21,33
# Analyzing scan position 21,34
# Analyzing scan position 21,35
# Analyzing scan position 21,36
# Analyzing scan position 21,37
# Analyzing scan position 21,38
# Analyzing scan position 21,39
# Analyzing scan position 21,40
# Analyzing scan position 21,41
# Analyzing scan position 21,42
# Analyzing scan position 21,43
# Analyzing scan position 21,44
# Analyzing scan position 21,45
# Analyzing scan position 21,46
# Analyzing scan position 21,47
# Analyzing scan position 21,48
# Analyzing scan position 21,49
# Analyzing scan position 21,50
# Analyzing scan position 21,51
# Analyzing scan position 21,52
# Analyzing scan position 21,53
# Analyzing scan position 21,54
# Analyzing scan position 21,55
# Analyzing scan position 21,56
# Analyzing scan position 21,57
# Analyzing scan position 21,58
# Analyzing scan position 21,59
# Analyzing scan position 22,0
# Analyzing scan position 22,1
# Analyzing scan position 22,2
# Analyzing scan position 22,3
# Analyzing scan position 22,4
# Analyzing scan position 22,5
# Analyzing scan position 22,6
# Analyzing scan position 22,7
# Analyzing scan position 22,8
# Analyzing scan position 22,9
# Analyzing scan position 22,10
# Analyzing scan position 22,11
# Analyzing scan position 22,12
# Analyzing scan position 22,13
# Analyzing scan position 22,14
# Analyzing scan position 22,15
# Analyzing scan position 22,16
# Analyzing scan position 22,17
# Analyzing scan position 22,18
# Analyzing scan position 22,19
# Analyzing scan position 22,20
# Analyzing scan position 22,21
# Analyzing scan position 22,22
# Analyzing scan position 22,23
# Analyzing scan position 22,24
# Analyzing scan position 22,25
# Analyzing scan position 22,26
# Analyzing scan position 22,27
# Analyzing scan position 22,28
# Analyzing scan position 22,29
# Analyzing scan position 22,30
# Analyzing scan position 22,31
# Analyzing scan position 22,32
# Analyzing scan position 22,33
# Analyzing scan position 22,34
# Analyzing scan position 22,35
# Analyzing scan position 22,36
# Analyzing scan position 22,37
# Analyzing scan position 22,38
# Analyzing scan position 22,39
# Analyzing scan position 22,40
# Analyzing scan position 22,41
# Analyzing scan position 22,42
# Analyzing scan position 22,43
# Analyzing scan position 22,44
# Analyzing scan position 22,45
# Analyzing scan position 22,46
# Analyzing scan position 22,47
# Analyzing scan position 22,48
# Analyzing scan position 22,49
# Analyzing scan position 22,50
# Analyzing scan position 22,51
# Analyzing scan position 22,52
# Analyzing scan position 22,53
# Analyzing scan position 22,54
# Analyzing scan position 22,55
# Analyzing scan position 22,56
# Analyzing scan position 22,57
# Analyzing scan position 22,58
# Analyzing scan position 22,59
# Analyzing scan position 23,0
# Analyzing scan position 23,1
# Analyzing scan position 23,2
# Analyzing scan position 23,3
# Analyzing scan position 23,4
# Analyzing scan position 23,5
# Analyzing scan position 23,6
# Analyzing scan position 23,7
# Analyzing scan position 23,8
# Analyzing scan position 23,9
# Analyzing scan position 23,10
# Analyzing scan position 23,11
# Analyzing scan position 23,12
# Analyzing scan position 23,13
# Analyzing scan position 23,14
# Analyzing scan position 23,15
# Analyzing scan position 23,16
# Analyzing scan position 23,17
# Analyzing scan position 23,18
# Analyzing scan position 23,19
# Analyzing scan position 23,20
# Analyzing scan position 23,21
# Analyzing scan position 23,22
# Analyzing scan position 23,23
# Analyzing scan position 23,24
# Analyzing scan position 23,25
# Analyzing scan position 23,26
# Analyzing scan position 23,27
# Analyzing scan position 23,28
# Analyzing scan position 23,29
# Analyzing scan position 23,30
# Analyzing scan position 23,31
# Analyzing scan position 23,32
# Analyzing scan position 23,33
# Analyzing scan position 23,34
# Analyzing scan position 23,35
# Analyzing scan position 23,36
# Analyzing scan position 23,37
# Analyzing scan position 23,38
# Analyzing scan position 23,39
# Analyzing scan position 23,40
# Analyzing scan position 23,41
# Analyzing scan position 23,42
# Analyzing scan position 23,43
# Analyzing scan position 23,44
# Analyzing scan position 23,45
# Analyzing scan position 23,46
# Analyzing scan position 23,47
# Analyzing scan position 23,48
# Analyzing scan position 23,49
# Analyzing scan position 23,50
# Analyzing scan position 23,51
# Analyzing scan position 23,52
# Analyzing scan position 23,53
# Analyzing scan position 23,54
# Analyzing scan position 23,55
# Analyzing scan position 23,56
# Analyzing scan position 23,57
# Analyzing scan position 23,58
# Analyzing scan position 23,59
# Analyzing scan position 24,0
# Analyzing scan position 24,1
# Analyzing scan position 24,2
# Analyzing scan position 24,3
# Analyzing scan position 24,4
# Analyzing scan position 24,5
# Analyzing scan position 24,6
# Analyzing scan position 24,7
# Analyzing scan position 24,8
# Analyzing scan position 24,9
# Analyzing scan position 24,10
# Analyzing scan position 24,11
# Analyzing scan position 24,12
# Analyzing scan position 24,13
# Analyzing scan position 24,14
# Analyzing scan position 24,15
# Analyzing scan position 24,16
# Analyzing scan position 24,17
# Analyzing scan position 24,18
# Analyzing scan position 24,19
# Analyzing scan position 24,20
# Analyzing scan position 24,21
# Analyzing scan position 24,22
# Analyzing scan position 24,23
# Analyzing scan position 24,24
# Analyzing scan position 24,25
# Analyzing scan position 24,26
# Analyzing scan position 24,27
# Analyzing scan position 24,28
# Analyzing scan position 24,29
# Analyzing scan position 24,30
# Analyzing scan position 24,31
# Analyzing scan position 24,32
# Analyzing scan position 24,33
# Analyzing scan position 24,34
# Analyzing scan position 24,35
# Analyzing scan position 24,36
# Analyzing scan position 24,37
# Analyzing scan position 24,38
# Analyzing scan position 24,39
# Analyzing scan position 24,40
# Analyzing scan position 24,41
# Analyzing scan position 24,42
# Analyzing scan position 24,43
# Analyzing scan position 24,44
# Analyzing scan position 24,45
# Analyzing scan position 24,46
# Analyzing scan position 24,47
# Analyzing scan position 24,48
# Analyzing scan position 24,49
# Analyzing scan position 24,50
# Analyzing scan position 24,51
# Analyzing scan position 24,52
# Analyzing scan position 24,53
# Analyzing scan position 24,54
# Analyzing scan position 24,55
# Analyzing scan position 24,56
# Analyzing scan position 24,57
# Analyzing scan position 24,58
# Analyzing scan position 24,59
# Analyzing scan position 25,0
# Analyzing scan position 25,1
# Analyzing scan position 25,2
# Analyzing scan position 25,3
# Analyzing scan position 25,4
# Analyzing scan position 25,5
# Analyzing scan position 25,6
# Analyzing scan position 25,7
# Analyzing scan position 25,8
# Analyzing scan position 25,9
# Analyzing scan position 25,10
# Analyzing scan position 25,11
# Analyzing scan position 25,12
# Analyzing scan position 25,13
# Analyzing scan position 25,14
# Analyzing scan position 25,15
# Analyzing scan position 25,16
# Analyzing scan position 25,17
# Analyzing scan position 25,18
# Analyzing scan position 25,19
# Analyzing scan position 25,20
# Analyzing scan position 25,21
# Analyzing scan position 25,22
# Analyzing scan position 25,23
# Analyzing scan position 25,24
# Analyzing scan position 25,25
# Analyzing scan position 25,26
# Analyzing scan position 25,27
# Analyzing scan position 25,28
# Analyzing scan position 25,29
# Analyzing scan position 25,30
# Analyzing scan position 25,31
# Analyzing scan position 25,32
# Analyzing scan position 25,33
# Analyzing scan position 25,34
# Analyzing scan position 25,35
# Analyzing scan position 25,36
# Analyzing scan position 25,37
# Analyzing scan position 25,38
# Analyzing scan position 25,39
# Analyzing scan position 25,40
# Analyzing scan position 25,41
# Analyzing scan position 25,42
# Analyzing scan position 25,43
# Analyzing scan position 25,44
# Analyzing scan position 25,45
# Analyzing scan position 25,46
# Analyzing scan position 25,47
# Analyzing scan position 25,48
# Analyzing scan position 25,49
# Analyzing scan position 25,50
# Analyzing scan position 25,51
# Analyzing scan position 25,52
# Analyzing scan position 25,53
# Analyzing scan position 25,54
# Analyzing scan position 25,55
# Analyzing scan position 25,56
# Analyzing scan position 25,57
# Analyzing scan position 25,58
# Analyzing scan position 25,59
# Analyzing scan position 26,0
# Analyzing scan position 26,1
# Analyzing scan position 26,2
# Analyzing scan position 26,3
# Analyzing scan position 26,4
# Analyzing scan position 26,5
# Analyzing scan position 26,6
# Analyzing scan position 26,7
# Analyzing scan position 26,8
# Analyzing scan position 26,9
# Analyzing scan position 26,10
# Analyzing scan position 26,11
# Analyzing scan position 26,12
# Analyzing scan position 26,13
# Analyzing scan position 26,14
# Analyzing scan position 26,15
# Analyzing scan position 26,16
# Analyzing scan position 26,17
# Analyzing scan position 26,18
# Analyzing scan position 26,19
# Analyzing scan position 26,20
# Analyzing scan position 26,21
# Analyzing scan position 26,22
# Analyzing scan position 26,23
# Analyzing scan position 26,24
# Analyzing scan position 26,25
# Analyzing scan position 26,26
# Analyzing scan position 26,27
# Analyzing scan position 26,28
# Analyzing scan position 26,29
# Analyzing scan position 26,30
# Analyzing scan position 26,31
# Analyzing scan position 26,32
# Analyzing scan position 26,33
# Analyzing scan position 26,34
# Analyzing scan position 26,35
# Analyzing scan position 26,36
# Analyzing scan position 26,37
# Analyzing scan position 26,38
# Analyzing scan position 26,39
# Analyzing scan position 26,40
# Analyzing scan position 26,41
# Analyzing scan position 26,42
# Analyzing scan position 26,43
# Analyzing scan position 26,44
# Analyzing scan position 26,45
# Analyzing scan position 26,46
# Analyzing scan position 26,47
# Analyzing scan position 26,48
# Analyzing scan position 26,49
# Analyzing scan position 26,50
# Analyzing scan position 26,51
# Analyzing scan position 26,52
# Analyzing scan position 26,53
# Analyzing scan position 26,54
# Analyzing scan position 26,55
# Analyzing scan position 26,56
# Analyzing scan position 26,57
# Analyzing scan position 26,58
# Analyzing scan position 26,59
# Analyzing scan position 27,0
# Analyzing scan position 27,1
# Analyzing scan position 27,2
# Analyzing scan position 27,3
# Analyzing scan position 27,4
# Analyzing scan position 27,5
# Analyzing scan position 27,6
# Analyzing scan position 27,7
# Analyzing scan position 27,8
# ...
# Analyzing scan position 51,5
# Analyzing scan position 51,6
# Analyzing scan position 51,7
# Analyzing scan position 51,8
# Analyzing scan position 51,9
# Analyzing scan position 51,10
# Analyzing scan position 51,11
# Analyzing scan position 51,12
# Analyzing scan position 51,13
# Analyzing scan position 51,14
# Analyzing scan position 51,15
# Analyzing scan position 51,16
# Analyzing scan position 51,17
# Analyzing scan position 51,18
# Analyzing scan position 51,19
# Analyzing scan position 51,20
# Analyzing scan position 51,21
# Analyzing scan position 51,22
# Analyzing scan position 51,23
# Analyzing scan position 51,24
# Analyzing scan position 51,25
# Analyzing scan position 51,26
# Analyzing scan position 51,27
# Analyzing scan position 51,28
# Analyzing scan position 51,29
# Analyzing scan position 51,30
# Analyzing scan position 51,31
# Analyzing scan position 51,32
# Analyzing scan position 51,33
# Analyzing scan position 51,34
# Analyzing scan position 51,35
# Analyzing scan position 51,36
# Analyzing scan position 51,37
# Analyzing scan position 51,38
# Analyzing scan position 51,39
# Analyzing scan position 51,40
# Analyzing scan position 51,41
# Analyzing scan position 51,42
# Analyzing scan position 51,43
# Analyzing scan position 51,44
# Analyzing scan position 51,45
# Analyzing scan position 51,46
# Analyzing scan position 51,47
# Analyzing scan position 51,48
# Analyzing scan position 51,49
# Analyzing scan position 51,50
# Analyzing scan position 51,51
# Analyzing scan position 51,52
# Analyzing scan position 51,53
# Analyzing scan position 51,54
# Analyzing scan position 51,55
# Analyzing scan position 51,56
# Analyzing scan position 51,57
# Analyzing scan position 51,58
# Analyzing scan position 51,59
# Analyzing scan position 52,0
# Analyzing scan position 52,1
# Analyzing scan position 52,2
# Analyzing scan position 52,3
# Analyzing scan position 52,4
# Analyzing scan position 52,5
# Analyzing scan position 52,6
# Analyzing scan position 52,7
# Analyzing scan position 52,8
# Analyzing scan position 52,9
# Analyzing scan position 52,10
# Analyzing scan position 52,11
# Analyzing scan position 52,12
# Analyzing scan position 52,13
# Analyzing scan position 52,14
# Analyzing scan position 52,15
# Analyzing scan position 52,16
# Analyzing scan position 52,17
# Analyzing scan position 52,18
# Analyzing scan position 52,19
# Analyzing scan position 52,20
# Analyzing scan position 52,21
# Analyzing scan position 52,22
# Analyzing scan position 52,23
# Analyzing scan position 52,24
# Analyzing scan position 52,25
# Analyzing scan position 52,26
# Analyzing scan position 52,27
# Analyzing scan position 52,28
# Analyzing scan position 52,29
# Analyzing scan position 52,30
# Analyzing scan position 52,31
# Analyzing scan position 52,32
# Analyzing scan position 52,33
# Analyzing scan position 52,34
# Analyzing scan position 52,35
# Analyzing scan position 52,36
# Analyzing scan position 52,37
# Analyzing scan position 52,38
# Analyzing scan position 52,39
# Analyzing scan position 52,40
# Analyzing scan position 52,41
# Analyzing scan position 52,42
# Analyzing scan position 52,43
# Analyzing scan position 52,44
# Analyzing scan position 52,45
# Analyzing scan position 52,46
# Analyzing scan position 52,47
# Analyzing scan position 52,48
# Analyzing scan position 52,49
# Analyzing scan position 52,50
# Analyzing scan position 52,51
# Analyzing scan position 52,52
# Analyzing scan position 52,53
# Analyzing scan position 52,54
# Analyzing scan position 52,55
# Analyzing scan position 52,56
# Analyzing scan position 52,57
# Analyzing scan position 52,58
# Analyzing scan position 52,59
# Analyzing scan position 53,0
# Analyzing scan position 53,1
# Analyzing scan position 53,2
# Analyzing scan position 53,3
# Analyzing scan position 53,4
# Analyzing scan position 53,5
# Analyzing scan position 53,6
# Analyzing scan position 53,7
# Analyzing scan position 53,8
# Analyzing scan position 53,9
# Analyzing scan position 53,10
# Analyzing scan position 53,11
# Analyzing scan position 53,12
# Analyzing scan position 53,13
# Analyzing scan position 53,14
# Analyzing scan position 53,15
# Analyzing scan position 53,16
# Analyzing scan position 53,17
# Analyzing scan position 53,18
# Analyzing scan position 53,19
# Analyzing scan position 53,20
# Analyzing scan position 53,21
# Analyzing scan position 53,22
# Analyzing scan position 53,23
# Analyzing scan position 53,24
# Analyzing scan position 53,25
# Analyzing scan position 53,26
# Analyzing scan position 53,27
# Analyzing scan position 53,28
# Analyzing scan position 53,29
# Analyzing scan position 53,30
# Analyzing scan position 53,31
# Analyzing scan position 53,32
# Analyzing scan position 53,33
# Analyzing scan position 53,34
# Analyzing scan position 53,35
# Analyzing scan position 53,36
# Analyzing scan position 53,37
# Analyzing scan position 53,38
# Analyzing scan position 53,39
# Analyzing scan position 53,40
# Analyzing scan position 53,41
# Analyzing scan position 53,42
# Analyzing scan position 53,43
# Analyzing scan position 53,44
# Analyzing scan position 53,45
# Analyzing scan position 53,46
# Analyzing scan position 53,47
# Analyzing scan position 53,48
# Analyzing scan position 53,49
# Analyzing scan position 53,50
# Analyzing scan position 53,51
# Analyzing scan position 53,52
# Analyzing scan position 53,53
# Analyzing scan position 53,54
# Analyzing scan position 53,55
# Analyzing scan position 53,56
# Analyzing scan position 53,57
# Analyzing scan position 53,58
# Analyzing scan position 53,59
# Analyzing scan position 54,0
# Analyzing scan position 54,1
# Analyzing scan position 54,2
# Analyzing scan position 54,3
# Analyzing scan position 54,4
# Analyzing scan position 54,5
# Analyzing scan position 54,6
# Analyzing scan position 54,7
# Analyzing scan position 54,8
# Analyzing scan position 54,9
# Analyzing scan position 54,10
# Analyzing scan position 54,11
# Analyzing scan position 54,12
# Analyzing scan position 54,13
# Analyzing scan position 54,14
# Analyzing scan position 54,15
# Analyzing scan position 54,16
# Analyzing scan position 54,17
# Analyzing scan position 54,18
# Analyzing scan position 54,19
# Analyzing scan position 54,20
# Analyzing scan position 54,21
# Analyzing scan position 54,22
# Analyzing scan position 54,23
# Analyzing scan position 54,24
# Analyzing scan position 54,25
# Analyzing scan position 54,26
# Analyzing scan position 54,27
# Analyzing scan position 54,28
# Analyzing scan position 54,29
# Analyzing scan position 54,30
# Analyzing scan position 54,31
# Analyzing scan position 54,32
# Analyzing scan position 54,33
# Analyzing scan position 54,34
# Analyzing scan position 54,35
# Analyzing scan position 54,36
# Analyzing scan position 54,37
# Analyzing scan position 54,38
# Analyzing scan position 54,39
# Analyzing scan position 54,40
# Analyzing scan position 54,41
# Analyzing scan position 54,42
# Analyzing scan position 54,43
# Analyzing scan position 54,44
# Analyzing scan position 54,45
# Analyzing scan position 54,46
# Analyzing scan position 54,47
# Analyzing scan position 54,48
# Analyzing scan position 54,49
# Analyzing scan position 54,50
# Analyzing scan position 54,51
# Analyzing scan position 54,52
# Analyzing scan position 54,53
# Analyzing scan position 54,54
# Analyzing scan position 54,55
# Analyzing scan position 54,56
# Analyzing scan position 54,57
# Analyzing scan position 54,58
# Analyzing scan position 54,59
# Analyzing scan position 55,0
# Analyzing scan position 55,1
# Analyzing scan position 55,2
# Analyzing scan position 55,3
# Analyzing scan position 55,4
# Analyzing scan position 55,5
# Analyzing scan position 55,6
# Analyzing scan position 55,7
# Analyzing scan position 55,8
# Analyzing scan position 55,9
# Analyzing scan position 55,10
# Analyzing scan position 55,11
# Analyzing scan position 55,12
# Analyzing scan position 55,13
# Analyzing scan position 55,14
# Analyzing scan position 55,15
# Analyzing scan position 55,16
# Analyzing scan position 55,17
# Analyzing scan position 55,18
# Analyzing scan position 55,19
# Analyzing scan position 55,20
# Analyzing scan position 55,21
# Analyzing scan position 55,22
# Analyzing scan position 55,23
# Analyzing scan position 55,24
# Analyzing scan position 55,25
# Analyzing scan position 55,26
# Analyzing scan position 55,27
# Analyzing scan position 55,28
# Analyzing scan position 55,29
# Analyzing scan position 55,30
# Analyzing scan position 55,31
# Analyzing scan position 55,32
# Analyzing scan position 55,33
# Analyzing scan position 55,34
# Analyzing scan position 55,35
# Analyzing scan position 55,36
# Analyzing scan position 55,37
# Analyzing scan position 55,38
# Analyzing scan position 55,39
# Analyzing scan position 55,40
# Analyzing scan position 55,41
# Analyzing scan position 55,42
# Analyzing scan position 55,43
# Analyzing scan position 55,44
# Analyzing scan position 55,45
# Analyzing scan position 55,46
# Analyzing scan position 55,47
# Analyzing scan position 55,48
# Analyzing scan position 55,49
# Analyzing scan position 55,50
# Analyzing scan position 55,51
# Analyzing scan position 55,52
# Analyzing scan position 55,53
# Analyzing scan position 55,54
# Analyzing scan position 55,55
# Analyzing scan position 55,56
# Analyzing scan position 55,57
# Analyzing scan position 55,58
# Analyzing scan position 55,59
# Analyzing scan position 56,0
# Analyzing scan position 56,1
# Analyzing scan position 56,2
# Analyzing scan position 56,3
# Analyzing scan position 56,4
# Analyzing scan position 56,5
# Analyzing scan position 56,6
# Analyzing scan position 56,7
# Analyzing scan position 56,8
# Analyzing scan position 56,9
# Analyzing scan position 56,10
# Analyzing scan position 56,11
# Analyzing scan position 56,12
# Analyzing scan position 56,13
# Analyzing scan position 56,14
# Analyzing scan position 56,15
# Analyzing scan position 56,16
# Analyzing scan position 56,17
# Analyzing scan position 56,18
# Analyzing scan position 56,19
# Analyzing scan position 56,20
# Analyzing scan position 56,21
# Analyzing scan position 56,22
# Analyzing scan position 56,23
# Analyzing scan position 56,24
# Analyzing scan position 56,25
# Analyzing scan position 56,26
# Analyzing scan position 56,27
# Analyzing scan position 56,28
# Analyzing scan position 56,29
# Analyzing scan position 56,30
# Analyzing scan position 56,31
# Analyzing scan position 56,32
# Analyzing scan position 56,33
# Analyzing scan position 56,34
# Analyzing scan position 56,35
# Analyzing scan position 56,36
# Analyzing scan position 56,37
# Analyzing scan position 56,38
# Analyzing scan position 56,39
# Analyzing scan position 56,40
# Analyzing scan position 56,41
# Analyzing scan position 56,42
# Analyzing scan position 56,43
# Analyzing scan position 56,44
# Analyzing scan position 56,45
# Analyzing scan position 56,46
# Analyzing scan position 56,47
# Analyzing scan position 56,48
# Analyzing scan position 56,49
# Analyzing scan position 56,50
# Analyzing scan position 56,51
# Analyzing scan position 56,52
# Analyzing scan position 56,53
# Analyzing scan position 56,54
# Analyzing scan position 56,55
# Analyzing scan position 56,56
# Analyzing scan position 56,57
# Analyzing scan position 56,58
# Analyzing scan position 56,59
# Analyzing scan position 57,0
# Analyzing scan position 57,1
# Analyzing scan position 57,2
# Analyzing scan position 57,3
# Analyzing scan position 57,4
# Analyzing scan position 57,5
# Analyzing scan position 57,6
# Analyzing scan position 57,7
# Analyzing scan position 57,8
# Analyzing scan position 57,9
# Analyzing scan position 57,10
# Analyzing scan position 57,11
# Analyzing scan position 57,12
# Analyzing scan position 57,13
# Analyzing scan position 57,14
# Analyzing scan position 57,15
# Analyzing scan position 57,16
# Analyzing scan position 57,17
# Analyzing scan position 57,18
# Analyzing scan position 57,19
# Analyzing scan position 57,20
# Analyzing scan position 57,21
# Analyzing scan position 57,22
# Analyzing scan position 57,23
# Analyzing scan position 57,24
# Analyzing scan position 57,25
# Analyzing scan position 57,26
# Analyzing scan position 57,27
# Analyzing scan position 57,28
# Analyzing scan position 57,29
# Analyzing scan position 57,30
# Analyzing scan position 57,31
# Analyzing scan position 57,32
# Analyzing scan position 57,33
# Analyzing scan position 57,34
# Analyzing scan position 57,35
# Analyzing scan position 57,36
# Analyzing scan position 57,37
# Analyzing scan position 57,38
# Analyzing scan position 57,39
# Analyzing scan position 57,40
# Analyzing scan position 57,41
# Analyzing scan position 57,42
# Analyzing scan position 57,43
# Analyzing scan position 57,44
# Analyzing scan position 57,45
# Analyzing scan position 57,46
# Analyzing scan position 57,47
# Analyzing scan position 57,48
# Analyzing scan position 57,49
# Analyzing scan position 57,50
# Analyzing scan position 57,51
# Analyzing scan position 57,52
# Analyzing scan position 57,53
# Analyzing scan position 57,54
# Analyzing scan position 57,55
# Analyzing scan position 57,56
# Analyzing scan position 57,57
# Analyzing scan position 57,58
# Analyzing scan position 57,59
# Analyzing scan position 58,0
# Analyzing scan position 58,1
# Analyzing scan position 58,2
# Analyzing scan position 58,3
# Analyzing scan position 58,4
# Analyzing scan position 58,5
# Analyzing scan position 58,6
# Analyzing scan position 58,7
# Analyzing scan position 58,8
# Analyzing scan position 58,9
# Analyzing scan position 58,10
# Analyzing scan position 58,11
# Analyzing scan position 58,12
# Analyzing scan position 58,13
# Analyzing scan position 58,14
# Analyzing scan position 58,15
# Analyzing scan position 58,16
# Analyzing scan position 58,17
# Analyzing scan position 58,18
# Analyzing scan position 58,19
# Analyzing scan position 58,20
# Analyzing scan position 58,21
# Analyzing scan position 58,22
# Analyzing scan position 58,23
# Analyzing scan position 58,24
# Analyzing scan position 58,25
# Analyzing scan position 58,26
# Analyzing scan position 58,27
# Analyzing scan position 58,28
# Analyzing scan position 58,29
# Analyzing scan position 58,30
# Analyzing scan position 58,31
# Analyzing scan position 58,32
# Analyzing scan position 58,33
# Analyzing scan position 58,34
# Analyzing scan position 58,35
# Analyzing scan position 58,36
# Analyzing scan position 58,37
# Analyzing scan position 58,38
# Analyzing scan position 58,39
# Analyzing scan position 58,40
# Analyzing scan position 58,41
# Analyzing scan position 58,42
# Analyzing scan position 58,43
# Analyzing scan position 58,44
# Analyzing scan position 58,45
# Analyzing scan position 58,46
# Analyzing scan position 58,47
# Analyzing scan position 58,48
# Analyzing scan position 58,49
# Analyzing scan position 58,50
# Analyzing scan position 58,51
# Analyzing scan position 58,52
# Analyzing scan position 58,53
# Analyzing scan position 58,54
# Analyzing scan position 58,55
# Analyzing scan position 58,56
# Analyzing scan position 58,57
# Analyzing scan position 58,58
# Analyzing scan position 58,59
# Analyzing scan position 59,0
# Analyzing scan position 59,1
# Analyzing scan position 59,2
# Analyzing scan position 59,3
# Analyzing scan position 59,4
# Analyzing scan position 59,5
# Analyzing scan position 59,6
# Analyzing scan position 59,7
# Analyzing scan position 59,8
# Analyzing scan position 59,9
# Analyzing scan position 59,10
# Analyzing scan position 59,11
# Analyzing scan position 59,12
# Analyzing scan position 59,13
# Analyzing scan position 59,14
# Analyzing scan position 59,15
# Analyzing scan position 59,16
# Analyzing scan position 59,17
# Analyzing scan position 59,18
# Analyzing scan position 59,19
# Analyzing scan position 59,20
# Analyzing scan position 59,21
# Analyzing scan position 59,22
# Analyzing scan position 59,23
# Analyzing scan position 59,24
# Analyzing scan position 59,25
# Analyzing scan position 59,26
# Analyzing scan position 59,27
# Analyzing scan position 59,28
# Analyzing scan position 59,29
# Analyzing scan position 59,30
# Analyzing scan position 59,31
# Analyzing scan position 59,32
# Analyzing scan position 59,33
# Analyzing scan position 59,34
# Analyzing scan position 59,35
# Analyzing scan position 59,36
# Analyzing scan position 59,37
# Analyzing scan position 59,38
# Analyzing scan position 59,39
# Analyzing scan position 59,40
# Analyzing scan position 59,41
# Analyzing scan position 59,42
# Analyzing scan position 59,43
# Analyzing scan position 59,44
# Analyzing scan position 59,45
# Analyzing scan position 59,46
# Analyzing scan position 59,47
# Analyzing scan position 59,48
# Analyzing scan position 59,49
# Analyzing scan position 59,50
# Analyzing scan position 59,51
# Analyzing scan position 59,52
# Analyzing scan position 59,53
# Analyzing scan position 59,54
# Analyzing scan position 59,55
# Analyzing scan position 59,56
# Analyzing scan position 59,57
# Analyzing scan position 59,58
# Analyzing scan position 59,59
# Finished in 0h 4m 33s

# %%
# Get the average deconvolution

average_deconvolution = np.zeros((dc.Q_Ny,dc.Q_Nx))

for i in range(len(Bragg_peak_point_list)):
    qx = int(Bragg_peak_point_list['qx'][i])
    qy = int(Bragg_peak_point_list['qy'][i])
    average_deconvolution[qx,qy] += Bragg_peak_point_list['intensity'][i]

# %%
# Plot

x0,y0=py4DSTEM.process.utils.get_CoM(average_deconvolution)
x0,y0=int(x0),int(y0)
rad=40

fig,((ax11,ax12),(ax21,ax22))=plt.subplots(2,2,figsize=(16,16))
ax11.matshow(average_deconvolution)
ax12.matshow(average_deconvolution[x0-rad:x0+rad,y0-rad:y0+rad])
ax21.matshow(average_deconvolution**0.25,cmap='jet')
ax22.matshow(average_deconvolution[x0-rad:x0+rad,y0-rad:y0+rad]**0.25,cmap='jet')
plt.show()

# %%
# Smooth average deconvolution

sigma_gaussianFilter2 = 2
average_deconvolution_gf = gaussian_filter(average_deconvolution, sigma_gaussianFilter2)

fig,((ax11,ax12),(ax21,ax22))=plt.subplots(2,2,figsize=(16,16))
ax11.matshow(average_deconvolution_gf)
ax12.matshow(average_deconvolution_gf[x0-rad:x0+rad,y0-rad:y0+rad])
ax21.matshow(average_deconvolution_gf**0.25)
ax22.matshow(average_deconvolution_gf[x0-rad:x0+rad,y0-rad:y0+rad]**0.25)
plt.show()

# %%
# Get average central beam position, from CoM of average deconvolution

central_beam_qx0, central_beam_qy0 = py4DSTEM.process.utils.get_CoM(average_deconvolution)

# %%
# Get the diffraction shifts for each DP, using closest peak to CoM of average deconvolution

diffraction_shifts1 = np.empty((2,dc.R_Nx,dc.R_Ny))
diffraction_shifts2 = np.empty((2,dc.R_Nx,dc.R_Ny))

for Ri in range(dc.R_Nx):
    for Rj in range(dc.R_Ny):
        mask = (Bragg_peak_point_list['rx']==Ri) & (Bragg_peak_point_list['ry']==Rj)
        point_list = Bragg_peak_point_list[mask]
        
        r2 = (point_list['qx']-central_beam_qx0)**2 + (point_list['qy']-central_beam_qy0)**2
        index = np.argmin(r2)
        diffraction_shifts1[0,Ri,Rj] = point_list['qx'][index]
        diffraction_shifts1[1,Ri,Rj] = point_list['qy'][index]
        
        index = np.argmax(point_list['intensity'])
        diffraction_shifts2[0,Ri,Rj] = point_list['qx'][index]
        diffraction_shifts2[1,Ri,Rj] = point_list['qy'][index]

# %%
# Subtract off average from diffraction shifts

#diffraction_shifts1[0,:,:]=diffraction_shifts1[0,:,:]-np.average(diffraction_shifts1[0,:,:])
#diffraction_shifts1[1,:,:]=diffraction_shifts1[1,:,:]-np.average(diffraction_shifts1[1,:,:])

#diffraction_shifts2[0,:,:]=diffraction_shifts2[0,:,:]-np.average(diffraction_shifts2[0,:,:])
#diffraction_shifts2[1,:,:]=diffraction_shifts2[1,:,:]-np.average(diffraction_shifts2[1,:,:])

# %%
# Plot shifts

fig,((ax11,ax12),(ax21,ax22)) = plt.subplots(2,2,figsize=(18,18))
ax11.matshow(diffraction_shifts1[0,:,:],cmap="RdBu")
ax12.matshow(diffraction_shifts1[1,:,:],cmap="RdBu")
ax21.matshow(diffraction_shifts2[0,:,:],cmap="RdBu")
ax22.matshow(diffraction_shifts2[1,:,:],cmap="RdBu")
plt.show()

# %%
# Take distance between diffraction shifts detemined from positions and intensities

diff2 = (diffraction_shifts1[0,:,:]-diffraction_shifts2[0,:,:])**2 + \
        (diffraction_shifts1[1,:,:]-diffraction_shifts2[1,:,:])**2

fig,(ax1,ax2,ax3) = plt.subplots(1,3,figsize=(17,5))
ax1.matshow(diff2)
ax2.hist(diff2.ravel(),bins=np.linspace(0,100000,100))
ax3.hist(diff2.ravel(),bins=np.linspace(0,100,100))
plt.show()

# %%
# Get the diffraction shifts for each DP
# Use only peaks where the peak (1) with highest intensity and (2) closest to CoM  are the same
# Mask off others

diffraction_shifts = np.zeros((2,dc.R_Nx,dc.R_Ny))
diffraction_shifts_known = np.zeros((dc.R_Nx,dc.R_Ny),dtype=bool)

for Ri in range(dc.R_Nx):
    for Rj in range(dc.R_Ny):
        mask = (Bragg_peak_point_list['rx']==Ri) & (Bragg_peak_point_list['ry']==Rj)
        point_list = Bragg_peak_point_list[mask]
        
        r2 = (point_list['qx']-central_beam_qx0)**2 + (point_list['qy']-central_beam_qy0)**2
        index1 = np.argmin(r2)
        index2 = np.argmax(point_list['intensity'])
        
        if index1 == index2:
            diffraction_shifts[0,Ri,Rj] = point_list['qx'][index1]
            diffraction_shifts[1,Ri,Rj] = point_list['qy'][index1]
            diffraction_shifts_known[Ri,Rj] = True

# %%
# Subtract off average from diffraction shifts

diffraction_shifts[0,:,:]=diffraction_shifts[0,:,:]-np.average(diffraction_shifts[0,diffraction_shifts_known])
diffraction_shifts[1,:,:]=diffraction_shifts[1,:,:]-np.average(diffraction_shifts[1,diffraction_shifts_known])

diffraction_shifts[0,diffraction_shifts_known==False] = 0
diffraction_shifts[1,diffraction_shifts_known==False] = 0

# %%
# Plot known shifts

fig,(ax1,ax2) = plt.subplots(1,2,figsize=(12,18))
ax1.matshow(diffraction_shifts[0,:,:],cmap="RdBu")
ax2.matshow(diffraction_shifts[1,:,:],cmap="RdBu")
plt.show()

# %% [markdown]
# ### 2c. Fit diffraction shifts
#
# * Fit plane (or polynomial, or Bezier surface...) to unscattered beam positions

# %%
# Fit with all datapoints

fit_function = py4DSTEM.process.fit.plane

popt_x, pcov_x, diffraction_shifts_fit_x_all = py4DSTEM.process.fit.fit_2D(fit_function, diffraction_shifts[0,:,:])
popt_y, pcov_y, diffraction_shifts_fit_y_all = py4DSTEM.process.fit.fit_2D(fit_function, diffraction_shifts[1,:,:])

fig,((ax11,ax12,ax13),(ax21,ax22,ax23))=plt.subplots(2,3,figsize=(24,16))
ax11.matshow(diffraction_shifts[0,:,:],cmap="RdBu")
ax12.matshow(diffraction_shifts_fit_x_all,cmap="RdBu")
ax13.matshow(diffraction_shifts[0,:,:]-diffraction_shifts_fit_x_all,cmap="RdBu")
ax21.matshow(diffraction_shifts[1,:,:],cmap="RdBu")
ax22.matshow(diffraction_shifts_fit_y_all,cmap="RdBu")
ax23.matshow(diffraction_shifts[1,:,:]-diffraction_shifts_fit_y_all,cmap="RdBu")
plt.show()

# %%
# Fit with only datapoints where diffraction_shifts_known==True

fit_function = py4DSTEM.process.fit.plane

popt_x, pcov_x, diffraction_shifts_fit_x = py4DSTEM.process.fit.fit_2D(fit_function, diffraction_shifts[0,:,:], data_mask=diffraction_shifts_known)
popt_y, pcov_y, diffraction_shifts_fit_y = py4DSTEM.process.fit.fit_2D(fit_function, diffraction_shifts[1,:,:], data_mask=diffraction_shifts_known)

fig,((ax11,ax12,ax13),(ax21,ax22,ax23))=plt.subplots(2,3,figsize=(24,16))
ax11.matshow(diffraction_shifts[0,:,:],cmap="RdBu")
ax12.matshow(diffraction_shifts_fit_x,cmap="RdBu")
ax13.matshow(diffraction_shifts[0,:,:]-diffraction_shifts_fit_x,cmap="RdBu")
ax21.matshow(diffraction_shifts[1,:,:],cmap="RdBu")
ax22.matshow(diffraction_shifts_fit_y,cmap="RdBu")
ax23.matshow(diffraction_shifts[1,:,:]-diffraction_shifts_fit_y,cmap="RdBu")
plt.show()

# %% [markdown]
# ## 3. Correct the diffraction shifts
#
# Finally, the diffraction pattern at each scan position is corrected for the calculated shifts.
#
# * Datacube
#     * Apply shifts at each beam positions
#     * Save new, processed datacube
# * Averaged deconvolution
#     * Apply shifts to recalculated averaged deconvolution

# %% [markdown]
# ### 3a. Correct diffraction shifts in raw datacube
#
# * Apply shifts at each beam positions
# * Save new, processed datacube

# %%
# Apply shifts

data4D_corrected = np.empty_like(dc.data4D,dtype='float32')

t0=time()
for i in range(dc.R_Nx):
    for j in range(dc.R_Ny):
        print("Shifting DP from scan position {},{}".format(i,j))
        data4D_corrected[i,j,:,:] = py4DSTEM.process.utils.get_shifted_ar(dc.data4D[i,j,:,:], 
                                                   -diffraction_shifts_fit_x[i,j],
                                                   -diffraction_shifts_fit_y[i,j])

t=time()-t0
print("Finished in {}h {}m {}s".format(int(t/3600),int(t/60),int(t%60)))
# Out:
# Shifting DP from scan position 0,0
# Shifting DP from scan position 0,1
# Shifting DP from scan position 0,2
# Shifting DP from scan position 0,3
# Shifting DP from scan position 0,4
# Shifting DP from scan position 0,5
# Shifting DP from scan position 0,6
# Shifting DP from scan position 0,7
# Shifting DP from scan position 0,8
# Shifting DP from scan position 0,9
# Shifting DP from scan position 0,10
# Shifting DP from scan position 0,11
# Shifting DP from scan position 0,12
# Shifting DP from scan position 0,13
# Shifting DP from scan position 0,14
# Shifting DP from scan position 0,15
# Shifting DP from scan position 0,16
# Shifting DP from scan position 0,17
# Shifting DP from scan position 0,18
# Shifting DP from scan position 0,19
# Shifting DP from scan position 0,20
# Shifting DP from scan position 0,21
# Shifting DP from scan position 0,22
# Shifting DP from scan position 0,23
# Shifting DP from scan position 0,24
# Shifting DP from scan position 0,25
# Shifting DP from scan position 0,26
# Shifting DP from scan position 0,27
# Shifting DP from scan position 0,28
# Shifting DP from scan position 0,29
# Shifting DP from scan position 0,30
# Shifting DP from scan position 0,31
# Shifting DP from scan position 0,32
# Shifting DP from scan position 0,33
# Shifting DP from scan position 0,34
# Shifting DP from scan position 0,35
# Shifting DP from scan position 0,36
# Shifting DP from scan position 0,37
# Shifting DP from scan position 0,38
# Shifting DP from scan position 0,39
# Shifting DP from scan position 0,40
# Shifting DP from scan position 0,41
# Shifting DP from scan position 0,42
# Shifting DP from scan position 0,43
# Shifting DP from scan position 0,44
# Shifting DP from scan position 0,45
# Shifting DP from scan position 0,46
# Shifting DP from scan position 0,47
# Shifting DP from scan position 0,48
# Shifting DP from scan position 0,49
# Shifting DP from scan position 0,50
# Shifting DP from scan position 0,51
# Shifting DP from scan position 0,52
# Shifting DP from scan position 0,53
# Shifting DP from scan position 0,54
# Shifting DP from scan position 0,55
# Shifting DP from scan position 0,56
# Shifting DP from scan position 0,57
# Shifting DP from scan position 0,58
# Shifting DP from scan position 0,59
# Shifting DP from scan position 1,0
# Shifting DP from scan position 1,1
# Shifting DP from scan position 1,2
# Shifting DP from scan position 1,3
# Shifting DP from scan position 1,4
# Shifting DP from scan position 1,5
# Shifting DP from scan position 1,6
# Shifting DP from scan position 1,7
# Shifting DP from scan position 1,8
# Shifting DP from scan position 1,9
# Shifting DP from scan position 1,10
# Shifting DP from scan position 1,11
# Shifting DP from scan position 1,12
# Shifting DP from scan position 1,13
# Shifting DP from scan position 1,14
# Shifting DP from scan position 1,15
# Shifting DP from scan position 1,16
# Shifting DP from scan position 1,17
# Shifting DP from scan position 1,18
# Shifting DP from scan position 1,19
# Shifting DP from scan position 1,20
# Shifting DP from scan position 1,21
# Shifting DP from scan position 1,22
# Shifting DP from scan position 1,23
# Shifting DP from scan position 1,24
# Shifting DP from scan position 1,25
# Shifting DP from scan position 1,26
# Shifting DP from scan position 1,27
# Shifting DP from scan position 1,28
# Shifting DP from scan position 1,29
# Shifting DP from scan position 1,30
# Shifting DP from scan position 1,31
# Shifting DP from scan position 1,32
# Shifting DP from scan position 1,33
# Shifting DP from scan position 1,34
# Shifting DP from scan position 1,35
# Shifting DP from scan position 1,36
# Shifting DP from scan position 1,37
# Shifting DP from scan position 1,38
# Shifting DP from scan position 1,39
# Shifting DP from scan position 1,40
# Shifting DP from scan position 1,41
# Shifting DP from scan position 1,42
# Shifting DP from scan position 1,43
# Shifting DP from scan position 1,44
# Shifting DP from scan position 1,45
# Shifting DP from scan position 1,46
# Shifting DP from scan position 1,47
# Shifting DP from scan position 1,48
# Shifting DP from scan position 1,49
# Shifting DP from scan position 1,50
# Shifting DP from scan position 1,51
# Shifting DP from scan position 1,52
# Shifting DP from scan position 1,53
# Shifting DP from scan position 1,54
# Shifting DP from scan position 1,55
# Shifting DP from scan position 1,56
# Shifting DP from scan position 1,57
# Shifting DP from scan position 1,58
# Shifting DP from scan position 1,59
# Shifting DP from scan position 2,0
# Shifting DP from scan position 2,1
# Shifting DP from scan position 2,2
# Shifting DP from scan position 2,3
# Shifting DP from scan position 2,4
# Shifting DP from scan position 2,5
# Shifting DP from scan position 2,6
# Shifting DP from scan position 2,7
# Shifting DP from scan position 2,8
# Shifting DP from scan position 2,9
# Shifting DP from scan position 2,10
# Shifting DP from scan position 2,11
# Shifting DP from scan position 2,12
# Shifting DP from scan position 2,13
# Shifting DP from scan position 2,14
# Shifting DP from scan position 2,15
# Shifting DP from scan position 2,16
# Shifting DP from scan position 2,17
# Shifting DP from scan position 2,18
# Shifting DP from scan position 2,19
# Shifting DP from scan position 2,20
# Shifting DP from scan position 2,21
# Shifting DP from scan position 2,22
# Shifting DP from scan position 2,23
# Shifting DP from scan position 2,24
# Shifting DP from scan position 2,25
# Shifting DP from scan position 2,26
# Shifting DP from scan position 2,27
# Shifting DP from scan position 2,28
# Shifting DP from scan position 2,29
# Shifting DP from scan position 2,30
# Shifting DP from scan position 2,31
# Shifting DP from scan position 2,32
# Shifting DP from scan position 2,33
# Shifting DP from scan position 2,34
# Shifting DP from scan position 2,35
# Shifting DP from scan position 2,36
# Shifting DP from scan position 2,37
# Shifting DP from scan position 2,38
# Shifting DP from scan position 2,39
# Shifting DP from scan position 2,40
# Shifting DP from scan position 2,41
# Shifting DP from scan position 2,42
# Shifting DP from scan position 2,43
# Shifting DP from scan position 2,44
# Shifting DP from scan position 2,45
# Shifting DP from scan position 2,46
# Shifting DP from scan position 2,47
# Shifting DP from scan position 2,48
# Shifting DP from scan position 2,49
# Shifting DP from scan position 2,50
# Shifting DP from scan position 2,51
# Shifting DP from scan position 2,52
# Shifting DP from scan position 2,53
# Shifting DP from scan position 2,54
# Shifting DP from scan position 2,55
# Shifting DP from scan position 2,56
# Shifting DP from scan position 2,57
# Shifting DP from scan position 2,58
# Shifting DP from scan position 2,59
# Shifting DP from scan position 3,0
# Shifting DP from scan position 3,1
# Shifting DP from scan position 3,2
# Shifting DP from scan position 3,3
# Shifting DP from scan position 3,4
# Shifting DP from scan position 3,5
# Shifting DP from scan position 3,6
# Shifting DP from scan position 3,7
# Shifting DP from scan position 3,8
# Shifting DP from scan position 3,9
# Shifting DP from scan position 3,10
# Shifting DP from scan position 3,11
# Shifting DP from scan position 3,12
# Shifting DP from scan position 3,13
# Shifting DP from scan position 3,14
# Shifting DP from scan position 3,15
# Shifting DP from scan position 3,16
# Shifting DP from scan position 3,17
# Shifting DP from scan position 3,18
# Shifting DP from scan position 3,19
# Shifting DP from scan position 3,20
# Shifting DP from scan position 3,21
# Shifting DP from scan position 3,22
# Shifting DP from scan position 3,23
# Shifting DP from scan position 3,24
# Shifting DP from scan position 3,25
# Shifting DP from scan position 3,26
# Shifting DP from scan position 3,27
# Shifting DP from scan position 3,28
# Shifting DP from scan position 3,29
# Shifting DP from scan position 3,30
# Shifting DP from scan position 3,31
# Shifting DP from scan position 3,32
# Shifting DP from scan position 3,33
# Shifting DP from scan position 3,34
# Shifting DP from scan position 3,35
# Shifting DP from scan position 3,36
# Shifting DP from scan position 3,37
# Shifting DP from scan position 3,38
# Shifting DP from scan position 3,39
# Shifting DP from scan position 3,40
# Shifting DP from scan position 3,41
# Shifting DP from scan position 3,42
# Shifting DP from scan position 3,43
# Shifting DP from scan position 3,44
# Shifting DP from scan position 3,45
# Shifting DP from scan position 3,46
# Shifting DP from scan position 3,47
# Shifting DP from scan position 3,48
# Shifting DP from scan position 3,49
# Shifting DP from scan position 3,50
# Shifting DP from scan position 3,51
# Shifting DP from scan position 3,52
# Shifting DP from scan position 3,53
# Shifting DP from scan position 3,54
# Shifting DP from scan position 3,55
# Shifting DP from scan position 3,56
# Shifting DP from scan position 3,57
# Shifting DP from scan position 3,58
# Shifting DP from scan position 3,59
# Shifting DP from scan position 4,0
# Shifting DP from scan position 4,1
# Shifting DP from scan position 4,2
# Shifting DP from scan position 4,3
# Shifting DP from scan position 4,4
# Shifting DP from scan position 4,5
# Shifting DP from scan position 4,6
# Shifting DP from scan position 4,7
# Shifting DP from scan position 4,8
# Shifting DP from scan position 4,9
# Shifting DP from scan position 4,10
# Shifting DP from scan position 4,11
# Shifting DP from scan position 4,12
# Shifting DP from scan position 4,13
# Shifting DP from scan position 4,14
# Shifting DP from scan position 4,15
# Shifting DP from scan position 4,16
# Shifting DP from scan position 4,17
# Shifting DP from scan position 4,18
# Shifting DP from scan position 4,19
# Shifting DP from scan position 4,20
# Shifting DP from scan position 4,21
# Shifting DP from scan position 4,22
# Shifting DP from scan position 4,23
# Shifting DP from scan position 4,24
# Shifting DP from scan position 4,25
# Shifting DP from scan position 4,26
# Shifting DP from scan position 4,27
# Shifting DP from scan position 4,28
# Shifting DP from scan position 4,29
# Shifting DP from scan position 4,30
# Shifting DP from scan position 4,31
# Shifting DP from scan position 4,32
# Shifting DP from scan position 4,33
# Shifting DP from scan position 4,34
# Shifting DP from scan position 4,35
# Shifting DP from scan position 4,36
# Shifting DP from scan position 4,37
# Shifting DP from scan position 4,38
# Shifting DP from scan position 4,39
# Shifting DP from scan position 4,40
# Shifting DP from scan position 4,41
# Shifting DP from scan position 4,42
# Shifting DP from scan position 4,43
# Shifting DP from scan position 4,44
# Shifting DP from scan position 4,45
# Shifting DP from scan position 4,46
# Shifting DP from scan position 4,47
# Shifting DP from scan position 4,48
# Shifting DP from scan position 4,49
# Shifting DP from scan position 4,50
# Shifting DP from scan position 4,51
# Shifting DP from scan position 4,52
# Shifting DP from scan position 4,53
# Shifting DP from scan position 4,54
# Shifting DP from scan position 4,55
# Shifting DP from scan position 4,56
# Shifting DP from scan position 4,57
# Shifting DP from scan position 4,58
# Shifting DP from scan position 4,59
# Shifting DP from scan position 5,0
# Shifting DP from scan position 5,1
# Shifting DP from scan position 5,2
# Shifting DP from scan position 5,3
# Shifting DP from scan position 5,4
# Shifting DP from scan position 5,5
# Shifting DP from scan position 5,6
# Shifting DP from scan position 5,7
# Shifting DP from scan position 5,8
# Shifting DP from scan position 5,9
# Shifting DP from scan position 5,10
# Shifting DP from scan position 5,11
# Shifting DP from scan position 5,12
# Shifting DP from scan position 5,13
# Shifting DP from scan position 5,14
# Shifting DP from scan position 5,15
# Shifting DP from scan position 5,16
# Shifting DP from scan position 5,17
# Shifting DP from scan position 5,18
# Shifting DP from scan position 5,19
# Shifting DP from scan position 5,20
# Shifting DP from scan position 5,21
# Shifting DP from scan position 5,22
# Shifting DP from scan position 5,23
# Shifting DP from scan position 5,24
# Shifting DP from scan position 5,25
# Shifting DP from scan position 5,26
# Shifting DP from scan position 5,27
# Shifting DP from scan position 5,28
# Shifting DP from scan position 5,29
# Shifting DP from scan position 5,30
# Shifting DP from scan position 5,31
# Shifting DP from scan position 5,32
# Shifting DP from scan position 5,33
# Shifting DP from scan position 5,34
# Shifting DP from scan position 5,35
# Shifting DP from scan position 5,36
# Shifting DP from scan position 5,37
# Shifting DP from scan position 5,38
# Shifting DP from scan position 5,39
# Shifting DP from scan position 5,40
# Shifting DP from scan position 5,41
# Shifting DP from scan position 5,42
# Shifting DP from scan position 5,43
# Shifting DP from scan position 5,44
# Shifting DP from scan position 5,45
# Shifting DP from scan position 5,46
# Shifting DP from scan position 5,47
# Shifting DP from scan position 5,48
# Shifting DP from scan position 5,49
# Shifting DP from scan position 5,50
# Shifting DP from scan position 5,51
# Shifting DP from scan position 5,52
# Shifting DP from scan position 5,53
# Shifting DP from scan position 5,54
# Shifting DP from scan position 5,55
# Shifting DP from scan position 5,56
# Shifting DP from scan position 5,57
# Shifting DP from scan position 5,58
# Shifting DP from scan position 5,59
# Shifting DP from scan position 6,0
# Shifting DP from scan position 6,1
# Shifting DP from scan position 6,2
# Shifting DP from scan position 6,3
# Shifting DP from scan position 6,4
# Shifting DP from scan position 6,5
# Shifting DP from scan position 6,6
# Shifting DP from scan position 6,7
# Shifting DP from scan position 6,8
# Shifting DP from scan position 6,9
# Shifting DP from scan position 6,10
# Shifting DP from scan position 6,11
# Shifting DP from scan position 6,12
# Shifting DP from scan position 6,13
# Shifting DP from scan position 6,14
# Shifting DP from scan position 6,15
# Shifting DP from scan position 6,16
# Shifting DP from scan position 6,17
# Shifting DP from scan position 6,18
# Shifting DP from scan position 6,19
# Shifting DP from scan position 6,20
# Shifting DP from scan position 6,21
# Shifting DP from scan position 6,22
# Shifting DP from scan position 6,23
# Shifting DP from scan position 6,24
# Shifting DP from scan position 6,25
# Shifting DP from scan position 6,26
# Shifting DP from scan position 6,27
# Shifting DP from scan position 6,28
# Shifting DP from scan position 6,29
# Shifting DP from scan position 6,30
# Shifting DP from scan position 6,31
# Shifting DP from scan position 6,32
# Shifting DP from scan position 6,33
# Shifting DP from scan position 6,34
# Shifting DP from scan position 6,35
# Shifting DP from scan position 6,36
# Shifting DP from scan position 6,37
# Shifting DP from scan position 6,38
# Shifting DP from scan position 6,39
# Shifting DP from scan position 6,40
# Shifting DP from scan position 6,41
# Shifting DP from scan position 6,42
# Shifting DP from scan position 6,43
# Shifting DP from scan position 6,44
# Shifting DP from scan position 6,45
# Shifting DP from scan position 6,46
# Shifting DP from scan position 6,47
# Shifting DP from scan position 6,48
# Shifting DP from scan position 6,49
# Shifting DP from scan position 6,50
# Shifting DP from scan position 6,51
# Shifting DP from scan position 6,52
# Shifting DP from scan position 6,53
# Shifting DP from scan position 6,54
# Shifting DP from scan position 6,55
# Shifting DP from scan position 6,56
# Shifting DP from scan position 6,57
# Shifting DP from scan position 6,58
# Shifting DP from scan position 6,59
# Shifting DP from scan position 7,0
# Shifting DP from scan position 7,1
# Shifting DP from scan position 7,2
# Shifting DP from scan position 7,3
# Shifting DP from scan position 7,4
# Shifting DP from scan position 7,5
# Shifting DP from scan position 7,6
# Shifting DP from scan position 7,7
# Shifting DP from scan position 7,8
# Shifting DP from scan position 7,9
# Shifting DP from scan position 7,10
# Shifting DP from scan position 7,11
# Shifting DP from scan position 7,12
# Shifting DP from scan position 7,13
# Shifting DP from scan position 7,14
# Shifting DP from scan position 7,15
# Shifting DP from scan position 7,16
# Shifting DP from scan position 7,17
# Shifting DP from scan position 7,18
# Shifting DP from scan position 7,19
# Shifting DP from scan position 7,20
# Shifting DP from scan position 7,21
# Shifting DP from scan position 7,22
# Shifting DP from scan position 7,23
# Shifting DP from scan position 7,24
# Shifting DP from scan position 7,25
# Shifting DP from scan position 7,26
# Shifting DP from scan position 7,27
# Shifting DP from scan position 7,28
# Shifting DP from scan position 7,29
# Shifting DP from scan position 7,30
# Shifting DP from scan position 7,31
# Shifting DP from scan position 7,32
# Shifting DP from scan position 7,33
# Shifting DP from scan position 7,34
# Shifting DP from scan position 7,35
# Shifting DP from scan position 7,36
# Shifting DP from scan position 7,37
# Shifting DP from scan position 7,38
# Shifting DP from scan position 7,39
# Shifting DP from scan position 7,40
# Shifting DP from scan position 7,41
# Shifting DP from scan position 7,42
# Shifting DP from scan position 7,43
# Shifting DP from scan position 7,44
# Shifting DP from scan position 7,45
# Shifting DP from scan position 7,46
# Shifting DP from scan position 7,47
# Shifting DP from scan position 7,48
# Shifting DP from scan position 7,49
# Shifting DP from scan position 7,50
# Shifting DP from scan position 7,51
# Shifting DP from scan position 7,52
# Shifting DP from scan position 7,53
# Shifting DP from scan position 7,54
# Shifting DP from scan position 7,55
# Shifting DP from scan position 7,56
# Shifting DP from scan position 7,57
# Shifting DP from scan position 7,58
# Shifting DP from scan position 7,59
# Shifting DP from scan position 8,0
# Shifting DP from scan position 8,1
# Shifting DP from scan position 8,2
# Shifting DP from scan position 8,3
# Shifting DP from scan position 8,4
# Shifting DP from scan position 8,5
# Shifting DP from scan position 8,6
# Shifting DP from scan position 8,7
# Shifting DP from scan position 8,8
# Shifting DP from scan position 8,9
# Shifting DP from scan position 8,10
# Shifting DP from scan position 8,11
# Shifting DP from scan position 8,12
# Shifting DP from scan position 8,13
# Shifting DP from scan position 8,14
# Shifting DP from scan position 8,15
# Shifting DP from scan position 8,16
# Shifting DP from scan position 8,17
# Shifting DP from scan position 8,18
# Shifting DP from scan position 8,19
# Shifting DP from scan position 8,20
# Shifting DP from scan position 8,21
# Shifting DP from scan position 8,22
# Shifting DP from scan position 8,23
# Shifting DP from scan position 8,24
# Shifting DP from scan position 8,25
# Shifting DP from scan position 8,26
# Shifting DP from scan position 8,27
# Shifting DP from scan position 8,28
# Shifting DP from scan position 8,29
# Shifting DP from scan position 8,30
# Shifting DP from scan position 8,31
# Shifting DP from scan position 8,32
# Shifting DP from scan position 8,33
# Shifting DP from scan position 8,34
# Shifting DP from scan position 8,35
# Shifting DP from scan position 8,36
# Shifting DP from scan position 8,37
# Shifting DP from scan position 8,38
# Shifting DP from scan position 8,39
# Shifting DP from scan position 8,40
# Shifting DP from scan position 8,41
# Shifting DP from scan position 8,42
# Shifting DP from scan position 8,43
# Shifting DP from scan position 8,44
# Shifting DP from scan position 8,45
# Shifting DP from scan position 8,46
# Shifting DP from scan position 8,47
# Shifting DP from scan position 8,48
# Shifting DP from scan position 8,49
# Shifting DP from scan position 8,50
# Shifting DP from scan position 8,51
# Shifting DP from scan position 8,52
# Shifting DP from scan position 8,53
# Shifting DP from scan position 8,54
# Shifting DP from scan position 8,55
# Shifting DP from scan position 8,56
# Shifting DP from scan position 8,57
# Shifting DP from scan position 8,58
# Shifting DP from scan position 8,59
# Shifting DP from scan position 9,0
# Shifting DP from scan position 9,1
# Shifting DP from scan position 9,2
# Shifting DP from scan position 9,3
# Shifting DP from scan position 9,4
# Shifting DP from scan position 9,5
# Shifting DP from scan position 9,6
# Shifting DP from scan position 9,7
# Shifting DP from scan position 9,8
# Shifting DP from scan position 9,9
# Shifting DP from scan position 9,10
# Shifting DP from scan position 9,11
# Shifting DP from scan position 9,12
# Shifting DP from scan position 9,13
# Shifting DP from scan position 9,14
# Shifting DP from scan position 9,15
# Shifting DP from scan position 9,16
# Shifting DP from scan position 9,17
# Shifting DP from scan position 9,18
# Shifting DP from scan position 9,19
# Shifting DP from scan position 9,20
# Shifting DP from scan position 9,21
# Shifting DP from scan position 9,22
# Shifting DP from scan position 9,23
# Shifting DP from scan position 9,24
# Shifting DP from scan position 9,25
# Shifting DP from scan position 9,26
# Shifting DP from scan position 9,27
# Shifting DP from scan position 9,28
# Shifting DP from scan position 9,29
# Shifting DP from scan position 9,30
# Shifting DP from scan position 9,31
# Shifting DP from scan position 9,32
# Shifting DP from scan position 9,33
# Shifting DP from scan position 9,34
# Shifting DP from scan position 9,35
# Shifting DP from scan position 9,36
# Shifting DP from scan position 9,37
# Shifting DP from scan position 9,38
# Shifting DP from scan position 9,39
# Shifting DP from scan position 9,40
# Shifting DP from scan position 9,41
# Shifting DP from scan position 9,42
# Shifting DP from scan position 9,43
# Shifting DP from scan position 9,44
# Shifting DP from scan position 9,45
# Shifting DP from scan position 9,46
# Shifting DP from scan position 9,47
# Shifting DP from scan position 9,48
# Shifting DP from scan position 9,49
# Shifting DP from scan position 9,50
# Shifting DP from scan position 9,51
# Shifting DP from scan position 9,52
# Shifting DP from scan position 9,53
# Shifting DP from scan position 9,54
# Shifting DP from scan position 9,55
# Shifting DP from scan position 9,56
# Shifting DP from scan position 9,57
# Shifting DP from scan position 9,58
# Shifting DP from scan position 9,59
# Shifting DP from scan position 10,0
# Shifting DP from scan position 10,1
# Shifting DP from scan position 10,2
# Shifting DP from scan position 10,3
# Shifting DP from scan position 10,4
# Shifting DP from scan position 10,5
# Shifting DP from scan position 10,6
# Shifting DP from scan position 10,7
# Shifting DP from scan position 10,8
# Shifting DP from scan position 10,9
# Shifting DP from scan position 10,10
# Shifting DP from scan position 10,11
# Shifting DP from scan position 10,12
# Shifting DP from scan position 10,13
# Shifting DP from scan position 10,14
# Shifting DP from scan position 10,15
# Shifting DP from scan position 10,16
# Shifting DP from scan position 10,17
# Shifting DP from scan position 10,18
# Shifting DP from scan position 10,19
# Shifting DP from scan position 10,20
# Shifting DP from scan position 10,21
# Shifting DP from scan position 10,22
# Shifting DP from scan position 10,23
# Shifting DP from scan position 10,24
# Shifting DP from scan position 10,25
# Shifting DP from scan position 10,26
# Shifting DP from scan position 10,27
# Shifting DP from scan position 10,28
# Shifting DP from scan position 10,29
# Shifting DP from scan position 10,30
# Shifting DP from scan position 10,31
# Shifting DP from scan position 10,32
# Shifting DP from scan position 10,33
# Shifting DP from scan position 10,34
# Shifting DP from scan position 10,35
# Shifting DP from scan position 10,36
# Shifting DP from scan position 10,37
# Shifting DP from scan position 10,38
# Shifting DP from scan position 10,39
# Shifting DP from scan position 10,40
# Shifting DP from scan position 10,41
# Shifting DP from scan position 10,42
# Shifting DP from scan position 10,43
# Shifting DP from scan position 10,44
# Shifting DP from scan position 10,45
# Shifting DP from scan position 10,46
# Shifting DP from scan position 10,47
# Shifting DP from scan position 10,48
# Shifting DP from scan position 10,49
# Shifting DP from scan position 10,50
# Shifting DP from scan position 10,51
# Shifting DP from scan position 10,52
# Shifting DP from scan position 10,53
# Shifting DP from scan position 10,54
# Shifting DP from scan position 10,55
# Shifting DP from scan position 10,56
# Shifting DP from scan position 10,57
# Shifting DP from scan position 10,58
# Shifting DP from scan position 10,59
# Shifting DP from scan position 11,0
# Shifting DP from scan position 11,1
# Shifting DP from scan position 11,2
# Shifting DP from scan position 11,3
# Shifting DP from scan position 11,4
# Shifting DP from scan position 11,5
# Shifting DP from scan position 11,6
# Shifting DP from scan position 11,7
# Shifting DP from scan position 11,8
# Shifting DP from scan position 11,9
# Shifting DP from scan position 11,10
# Shifting DP from scan position 11,11
# Shifting DP from scan position 11,12
# Shifting DP from scan position 11,13
# Shifting DP from scan position 11,14
# Shifting DP from scan position 11,15
# Shifting DP from scan position 11,16
# Shifting DP from scan position 11,17
# Shifting DP from scan position 11,18
# Shifting DP from scan position 11,19
# Shifting DP from scan position 11,20
# Shifting DP from scan position 11,21
# Shifting DP from scan position 11,22
# Shifting DP from scan position 11,23
# Shifting DP from scan position 11,24
# Shifting DP from scan position 11,25
# Shifting DP from scan position 11,26
# Shifting DP from scan position 11,27
# Shifting DP from scan position 11,28
# Shifting DP from scan position 11,29
# Shifting DP from scan position 11,30
# Shifting DP from scan position 11,31
# Shifting DP from scan position 11,32
# Shifting DP from scan position 11,33
# Shifting DP from scan position 11,34
# Shifting DP from scan position 11,35
# Shifting DP from scan position 11,36
# Shifting DP from scan position 11,37
# Shifting DP from scan position 11,38
# Shifting DP from scan position 11,39
# Shifting DP from scan position 11,40
# Shifting DP from scan position 11,41
# Shifting DP from scan position 11,42
# Shifting DP from scan position 11,43
# Shifting DP from scan position 11,44
# Shifting DP from scan position 11,45
# Shifting DP from scan position 11,46
# Shifting DP from scan position 11,47
# Shifting DP from scan position 11,48
# Shifting DP from scan position 11,49
# Shifting DP from scan position 11,50
# Shifting DP from scan position 11,51
# Shifting DP from scan position 11,52
# Shifting DP from scan position 11,53
# Shifting DP from scan position 11,54
# Shifting DP from scan position 11,55
# Shifting DP from scan position 11,56
# Shifting DP from scan position 11,57
# Shifting DP from scan position 11,58
# Shifting DP from scan position 11,59
# Shifting DP from scan position 12,0
# Shifting DP from scan position 12,1
# Shifting DP from scan position 12,2
# Shifting DP from scan position 12,3
# Shifting DP from scan position 12,4
# Shifting DP from scan position 12,5
# Shifting DP from scan position 12,6
# Shifting DP from scan position 12,7
# Shifting DP from scan position 12,8
# Shifting DP from scan position 12,9
# Shifting DP from scan position 12,10
# Shifting DP from scan position 12,11
# Shifting DP from scan position 12,12
# Shifting DP from scan position 12,13
# Shifting DP from scan position 12,14
# Shifting DP from scan position 12,15
# Shifting DP from scan position 12,16
# Shifting DP from scan position 12,17
# Shifting DP from scan position 12,18
# Shifting DP from scan position 12,19
# Shifting DP from scan position 12,20
# Shifting DP from scan position 12,21
# Shifting DP from scan position 12,22
# Shifting DP from scan position 12,23
# Shifting DP from scan position 12,24
# Shifting DP from scan position 12,25
# Shifting DP from scan position 12,26
# Shifting DP from scan position 12,27
# Shifting DP from scan position 12,28
# Shifting DP from scan position 12,29
# Shifting DP from scan position 12,30
# Shifting DP from scan position 12,31
# Shifting DP from scan position 12,32
# Shifting DP from scan position 12,33
# Shifting DP from scan position 12,34
# Shifting DP from scan position 12,35
# Shifting DP from scan position 12,36
# Shifting DP from scan position 12,37
# Shifting DP from scan position 12,38
# Shifting DP from scan position 12,39
# Shifting DP from scan position 12,40
# Shifting DP from scan position 12,41
# Shifting DP from scan position 12,42
# Shifting DP from scan position 12,43
# Shifting DP from scan position 12,44
# Shifting DP from scan position 12,45
# Shifting DP from scan position 12,46
# Shifting DP from scan position 12,47
# Shifting DP from scan position 12,48
# Shifting DP from scan position 12,49
# Shifting DP from scan position 12,50
# Shifting DP from scan position 12,51
# Shifting DP from scan position 12,52
# Shifting DP from scan position 12,53
# Shifting DP from scan position 12,54
# Shifting DP from scan position 12,55
# Shifting DP from scan position 12,56
# Shifting DP from scan position 12,57
# Shifting DP from scan position 12,58
# Shifting DP from scan position 12,59
# Shifting DP from scan position 13,0
# Shifting DP from scan position 13,1
# Shifting DP from scan position 13,2
# Shifting DP from scan position 13,3
# Shifting DP from scan position 13,4
# Shifting DP from scan position 13,5
# Shifting DP from scan position 13,6
# Shifting DP from scan position 13,7
# Shifting DP from scan position 13,8
# Shifting DP from scan position 13,9
# Shifting DP from scan position 13,10
# Shifting DP from scan position 13,11
# Shifting DP from scan position 13,12
# Shifting DP from scan position 13,13
# Shifting DP from scan position 13,14
# Shifting DP from scan position 13,15
# Shifting DP from scan position 13,16
# Shifting DP from scan position 13,17
# Shifting DP from scan position 13,18
# Shifting DP from scan position 13,19
# Shifting DP from scan position 13,20
# Shifting DP from scan position 13,21
# Shifting DP from scan position 13,22
# Shifting DP from scan position 13,23
# Shifting DP from scan position 13,24
# Shifting DP from scan position 13,25
# Shifting DP from scan position 13,26
# Shifting DP from scan position 13,27
# Shifting DP from scan position 13,28
# Shifting DP from scan position 13,29
# Shifting DP from scan position 13,30
# Shifting DP from scan position 13,31
# Shifting DP from scan position 13,32
# Shifting DP from scan position 13,33
# Shifting DP from scan position 13,34
# Shifting DP from scan position 13,35
# Shifting DP from scan position 13,36
# Shifting DP from scan position 13,37
# Shifting DP from scan position 13,38
# Shifting DP from scan position 13,39
# Shifting DP from scan position 13,40
# Shifting DP from scan position 13,41
# Shifting DP from scan position 13,42
# Shifting DP from scan position 13,43
# Shifting DP from scan position 13,44
# Shifting DP from scan position 13,45
# Shifting DP from scan position 13,46
# Shifting DP from scan position 13,47
# Shifting DP from scan position 13,48
# Shifting DP from scan position 13,49
# Shifting DP from scan position 13,50
# Shifting DP from scan position 13,51
# Shifting DP from scan position 13,52
# Shifting DP from scan position 13,53
# Shifting DP from scan position 13,54
# Shifting DP from scan position 13,55
# Shifting DP from scan position 13,56
# Shifting DP from scan position 13,57
# Shifting DP from scan position 13,58
# Shifting DP from scan position 13,59
# Shifting DP from scan position 14,0
# Shifting DP from scan position 14,1
# Shifting DP from scan position 14,2
# Shifting DP from scan position 14,3
# Shifting DP from scan position 14,4
# Shifting DP from scan position 14,5
# Shifting DP from scan position 14,6
# Shifting DP from scan position 14,7
# Shifting DP from scan position 14,8
# Shifting DP from scan position 14,9
# Shifting DP from scan position 14,10
# Shifting DP from scan position 14,11
# Shifting DP from scan position 14,12
# Shifting DP from scan position 14,13
# Shifting DP from scan position 14,14
# Shifting DP from scan position 14,15
# Shifting DP from scan position 14,16
# Shifting DP from scan position 14,17
# Shifting DP from scan position 14,18
# Shifting DP from scan position 14,19
# Shifting DP from scan position 14,20
# Shifting DP from scan position 14,21
# Shifting DP from scan position 14,22
# Shifting DP from scan position 14,23
# Shifting DP from scan position 14,24
# Shifting DP from scan position 14,25
# Shifting DP from scan position 14,26
# Shifting DP from scan position 14,27
# Shifting DP from scan position 14,28
# Shifting DP from scan position 14,29
# Shifting DP from scan position 14,30
# Shifting DP from scan position 14,31
# Shifting DP from scan position 14,32
# Shifting DP from scan position 14,33
# Shifting DP from scan position 14,34
# Shifting DP from scan position 14,35
# Shifting DP from scan position 14,36
# Shifting DP from scan position 14,37
# Shifting DP from scan position 14,38
# Shifting DP from scan position 14,39
# Shifting DP from scan position 14,40
# Shifting DP from scan position 14,41
# Shifting DP from scan position 14,42
# Shifting DP from scan position 14,43
# Shifting DP from scan position 14,44
# Shifting DP from scan position 14,45
# Shifting DP from scan position 14,46
# Shifting DP from scan position 14,47
# Shifting DP from scan position 14,48
# Shifting DP from scan position 14,49
# Shifting DP from scan position 14,50
# Shifting DP from scan position 14,51
# Shifting DP from scan position 14,52
# Shifting DP from scan position 14,53
# Shifting DP from scan position 14,54
# Shifting DP from scan position 14,55
# Shifting DP from scan position 14,56
# Shifting DP from scan position 14,57
# Shifting DP from scan position 14,58
# Shifting DP from scan position 14,59
# Shifting DP from scan position 15,0
# Shifting DP from scan position 15,1
# Shifting DP from scan position 15,2
# Shifting DP from scan position 15,3
# Shifting DP from scan position 15,4
# Shifting DP from scan position 15,5
# Shifting DP from scan position 15,6
# Shifting DP from scan position 15,7
# Shifting DP from scan position 15,8
# Shifting DP from scan position 15,9
# Shifting DP from scan position 15,10
# Shifting DP from scan position 15,11
# Shifting DP from scan position 15,12
# Shifting DP from scan position 15,13
# Shifting DP from scan position 15,14
# Shifting DP from scan position 15,15
# Shifting DP from scan position 15,16
# Shifting DP from scan position 15,17
# Shifting DP from scan position 15,18
# Shifting DP from scan position 15,19
# Shifting DP from scan position 15,20
# Shifting DP from scan position 15,21
# Shifting DP from scan position 15,22
# Shifting DP from scan position 15,23
# Shifting DP from scan position 15,24
# Shifting DP from scan position 15,25
# Shifting DP from scan position 15,26
# Shifting DP from scan position 15,27
# Shifting DP from scan position 15,28
# Shifting DP from scan position 15,29
# Shifting DP from scan position 15,30
# Shifting DP from scan position 15,31
# Shifting DP from scan position 15,32
# Shifting DP from scan position 15,33
# Shifting DP from scan position 15,34
# Shifting DP from scan position 15,35
# Shifting DP from scan position 15,36
# Shifting DP from scan position 15,37
# Shifting DP from scan position 15,38
# Shifting DP from scan position 15,39
# Shifting DP from scan position 15,40
# Shifting DP from scan position 15,41
# Shifting DP from scan position 15,42
# Shifting DP from scan position 15,43
# Shifting DP from scan position 15,44
# Shifting DP from scan position 15,45
# Shifting DP from scan position 15,46
# Shifting DP from scan position 15,47
# Shifting DP from scan position 15,48
# Shifting DP from scan position 15,49
# Shifting DP from scan position 15,50
# Shifting DP from scan position 15,51
# Shifting DP from scan position 15,52
# Shifting DP from scan position 15,53
# Shifting DP from scan position 15,54
# Shifting DP from scan position 15,55
# Shifting DP from scan position 15,56
# Shifting DP from scan position 15,57
# Shifting DP from scan position 15,58
# Shifting DP from scan position 15,59
# Shifting DP from scan position 16,0
# Shifting DP from scan position 16,1
# Shifting DP from scan position 16,2
# Shifting DP from scan position 16,3
# Shifting DP from scan position 16,4
# Shifting DP from scan position 16,5
# Shifting DP from scan position 16,6
# Shifting DP from scan position 16,7
# Shifting DP from scan position 16,8
# Shifting DP from scan position 16,9
# Shifting DP from scan position 16,10
# Shifting DP from scan position 16,11
# Shifting DP from scan position 16,12
# Shifting DP from scan position 16,13
# Shifting DP from scan position 16,14
# Shifting DP from scan position 16,15
# Shifting DP from scan position 16,16
# Shifting DP from scan position 16,17
# Shifting DP from scan position 16,18
# Shifting DP from scan position 16,19
# Shifting DP from scan position 16,20
# Shifting DP from scan position 16,21
# Shifting DP from scan position 16,22
# Shifting DP from scan position 16,23
# Shifting DP from scan position 16,24
# Shifting DP from scan position 16,25
# Shifting DP from scan position 16,26
# Shifting DP from scan position 16,27
# Shifting DP from scan position 16,28
# Shifting DP from scan position 16,29
# Shifting DP from scan position 16,30
# Shifting DP from scan position 16,31
# Shifting DP from scan position 16,32
# Shifting DP from scan position 16,33
# Shifting DP from scan position 16,34
# Shifting DP from scan position 16,35
# Shifting DP from scan position 16,36
# Shifting DP from scan position 16,37
# Shifting DP from scan position 16,38
# Shifting DP from scan position 16,39
# Shifting DP from scan position 16,40
# Shifting DP from scan position 16,41
# Shifting DP from scan position 16,42
# Shifting DP from scan position 16,43
# Shifting DP from scan position 16,44
# Shifting DP from scan position 16,45
# Shifting DP from scan position 16,46
# Shifting DP from scan position 16,47
# Shifting DP from scan position 16,48
# Shifting DP from scan position 16,49
# Shifting DP from scan position 16,50
# Shifting DP from scan position 16,51
# Shifting DP from scan position 16,52
# Shifting DP from scan position 16,53
# Shifting DP from scan position 16,54
# Shifting DP from scan position 16,55
# Shifting DP from scan position 16,56
# Shifting DP from scan position 16,57
# Shifting DP from scan position 16,58
# Shifting DP from scan position 16,59
# Shifting DP from scan position 17,0
# Shifting DP from scan position 17,1
# Shifting DP from scan position 17,2
# Shifting DP from scan position 17,3
# Shifting DP from scan position 17,4
# Shifting DP from scan position 17,5
# Shifting DP from scan position 17,6
# Shifting DP from scan position 17,7
# Shifting DP from scan position 17,8
# Shifting DP from scan position 17,9
# Shifting DP from scan position 17,10
# Shifting DP from scan position 17,11
# Shifting DP from scan position 17,12
# Shifting DP from scan position 17,13
# Shifting DP from scan position 17,14
# Shifting DP from scan position 17,15
# Shifting DP from scan position 17,16
# Shifting DP from scan position 17,17
# Shifting DP from scan position 17,18
# Shifting DP from scan position 17,19
# Shifting DP from scan position 17,20
# Shifting DP from scan position 17,21
# Shifting DP from scan position 17,22
# Shifting DP from scan position 17,23
# Shifting DP from scan position 17,24
# Shifting DP from scan position 17,25
# Shifting DP from scan position 17,26
# Shifting DP from scan position 17,27
# Shifting DP from scan position 17,28
# Shifting DP from scan position 17,29
# Shifting DP from scan position 17,30
# Shifting DP from scan position 17,31
# Shifting DP from scan position 17,32
# Shifting DP from scan position 17,33
# Shifting DP from scan position 17,34
# Shifting DP from scan position 17,35
# Shifting DP from scan position 17,36
# Shifting DP from scan position 17,37
# Shifting DP from scan position 17,38
# Shifting DP from scan position 17,39
# Shifting DP from scan position 17,40
# Shifting DP from scan position 17,41
# Shifting DP from scan position 17,42
# Shifting DP from scan position 17,43
# Shifting DP from scan position 17,44
# Shifting DP from scan position 17,45
# Shifting DP from scan position 17,46
# Shifting DP from scan position 17,47
# Shifting DP from scan position 17,48
# Shifting DP from scan position 17,49
# Shifting DP from scan position 17,50
# Shifting DP from scan position 17,51
# Shifting DP from scan position 17,52
# Shifting DP from scan position 17,53
# Shifting DP from scan position 17,54
# Shifting DP from scan position 17,55
# Shifting DP from scan position 17,56
# Shifting DP from scan position 17,57
# Shifting DP from scan position 17,58
# Shifting DP from scan position 17,59
# Shifting DP from scan position 18,0
# Shifting DP from scan position 18,1
# Shifting DP from scan position 18,2
# Shifting DP from scan position 18,3
# Shifting DP from scan position 18,4
# Shifting DP from scan position 18,5
# Shifting DP from scan position 18,6
# Shifting DP from scan position 18,7
# Shifting DP from scan position 18,8
# Shifting DP from scan position 18,9
# Shifting DP from scan position 18,10
# Shifting DP from scan position 18,11
# Shifting DP from scan position 18,12
# Shifting DP from scan position 18,13
# Shifting DP from scan position 18,14
# Shifting DP from scan position 18,15
# Shifting DP from scan position 18,16
# Shifting DP from scan position 18,17
# Shifting DP from scan position 18,18
# Shifting DP from scan position 18,19
# Shifting DP from scan position 18,20
# Shifting DP from scan position 18,21
# Shifting DP from scan position 18,22
# Shifting DP from scan position 18,23
# Shifting DP from scan position 18,24
# Shifting DP from scan position 18,25
# Shifting DP from scan position 18,26
# Shifting DP from scan position 18,27
# Shifting DP from scan position 18,28
# Shifting DP from scan position 18,29
# Shifting DP from scan position 18,30
# Shifting DP from scan position 18,31
# Shifting DP from scan position 18,32
# Shifting DP from scan position 18,33
# Shifting DP from scan position 18,34
# Shifting DP from scan position 18,35
# Shifting DP from scan position 18,36
# Shifting DP from scan position 18,37
# Shifting DP from scan position 18,38
# Shifting DP from scan position 18,39
# Shifting DP from scan position 18,40
# Shifting DP from scan position 18,41
# Shifting DP from scan position 18,42
# Shifting DP from scan position 18,43
# Shifting DP from scan position 18,44
# Shifting DP from scan position 18,45
# Shifting DP from scan position 18,46
# Shifting DP from scan position 18,47
# Shifting DP from scan position 18,48
# Shifting DP from scan position 18,49
# Shifting DP from scan position 18,50
# Shifting DP from scan position 18,51
# Shifting DP from scan position 18,52
# Shifting DP from scan position 18,53
# Shifting DP from scan position 18,54
# Shifting DP from scan position 18,55
# Shifting DP from scan position 18,56
# Shifting DP from scan position 18,57
# Shifting DP from scan position 18,58
# Shifting DP from scan position 18,59
# Shifting DP from scan position 19,0
# Shifting DP from scan position 19,1
# Shifting DP from scan position 19,2
# Shifting DP from scan position 19,3
# Shifting DP from scan position 19,4
# Shifting DP from scan position 19,5
# Shifting DP from scan position 19,6
# Shifting DP from scan position 19,7
# Shifting DP from scan position 19,8
# Shifting DP from scan position 19,9
# Shifting DP from scan position 19,10
# Shifting DP from scan position 19,11
# Shifting DP from scan position 19,12
# Shifting DP from scan position 19,13
# Shifting DP from scan position 19,14
# Shifting DP from scan position 19,15
# Shifting DP from scan position 19,16
# Shifting DP from scan position 19,17
# Shifting DP from scan position 19,18
# Shifting DP from scan position 19,19
# Shifting DP from scan position 19,20
# Shifting DP from scan position 19,21
# Shifting DP from scan position 19,22
# Shifting DP from scan position 19,23
# Shifting DP from scan position 19,24
# Shifting DP from scan position 19,25
# Shifting DP from scan position 19,26
# Shifting DP from scan position 19,27
# Shifting DP from scan position 19,28
# Shifting DP from scan position 19,29
# Shifting DP from scan position 19,30
# Shifting DP from scan position 19,31
# Shifting DP from scan position 19,32
# Shifting DP from scan position 19,33
# Shifting DP from scan position 19,34
# Shifting DP from scan position 19,35
# Shifting DP from scan position 19,36
# Shifting DP from scan position 19,37
# Shifting DP from scan position 19,38
# Shifting DP from scan position 19,39
# Shifting DP from scan position 19,40
# Shifting DP from scan position 19,41
# Shifting DP from scan position 19,42
# Shifting DP from scan position 19,43
# Shifting DP from scan position 19,44
# Shifting DP from scan position 19,45
# Shifting DP from scan position 19,46
# Shifting DP from scan position 19,47
# Shifting DP from scan position 19,48
# Shifting DP from scan position 19,49
# Shifting DP from scan position 19,50
# Shifting DP from scan position 19,51
# Shifting DP from scan position 19,52
# Shifting DP from scan position 19,53
# Shifting DP from scan position 19,54
# Shifting DP from scan position 19,55
# Shifting DP from scan position 19,56
# Shifting DP from scan position 19,57
# Shifting DP from scan position 19,58
# Shifting DP from scan position 19,59
# Shifting DP from scan position 20,0
# Shifting DP from scan position 20,1
# Shifting DP from scan position 20,2
# Shifting DP from scan position 20,3
# Shifting DP from scan position 20,4
# Shifting DP from scan position 20,5
# Shifting DP from scan position 20,6
# Shifting DP from scan position 20,7
# Shifting DP from scan position 20,8
# Shifting DP from scan position 20,9
# Shifting DP from scan position 20,10
# Shifting DP from scan position 20,11
# Shifting DP from scan position 20,12
# Shifting DP from scan position 20,13
# Shifting DP from scan position 20,14
# Shifting DP from scan position 20,15
# Shifting DP from scan position 20,16
# Shifting DP from scan position 20,17
# Shifting DP from scan position 20,18
# Shifting DP from scan position 20,19
# Shifting DP from scan position 20,20
# Shifting DP from scan position 20,21
# Shifting DP from scan position 20,22
# Shifting DP from scan position 20,23
# Shifting DP from scan position 20,24
# Shifting DP from scan position 20,25
# Shifting DP from scan position 20,26
# Shifting DP from scan position 20,27
# Shifting DP from scan position 20,28
# Shifting DP from scan position 20,29
# Shifting DP from scan position 20,30
# Shifting DP from scan position 20,31
# Shifting DP from scan position 20,32
# Shifting DP from scan position 20,33
# Shifting DP from scan position 20,34
# Shifting DP from scan position 20,35
# Shifting DP from scan position 20,36
# Shifting DP from scan position 20,37
# Shifting DP from scan position 20,38
# Shifting DP from scan position 20,39
# Shifting DP from scan position 20,40
# Shifting DP from scan position 20,41
# Shifting DP from scan position 20,42
# Shifting DP from scan position 20,43
# Shifting DP from scan position 20,44
# Shifting DP from scan position 20,45
# Shifting DP from scan position 20,46
# Shifting DP from scan position 20,47
# Shifting DP from scan position 20,48
# Shifting DP from scan position 20,49
# Shifting DP from scan position 20,50
# Shifting DP from scan position 20,51
# Shifting DP from scan position 20,52
# Shifting DP from scan position 20,53
# Shifting DP from scan position 20,54
# Shifting DP from scan position 20,55
# Shifting DP from scan position 20,56
# Shifting DP from scan position 20,57
# Shifting DP from scan position 20,58
# Shifting DP from scan position 20,59
# Shifting DP from scan position 21,0
# Shifting DP from scan position 21,1
# Shifting DP from scan position 21,2
# Shifting DP from scan position 21,3
# Shifting DP from scan position 21,4
# Shifting DP from scan position 21,5
# Shifting DP from scan position 21,6
# Shifting DP from scan position 21,7
# Shifting DP from scan position 21,8
# Shifting DP from scan position 21,9
# Shifting DP from scan position 21,10
# Shifting DP from scan position 21,11
# Shifting DP from scan position 21,12
# Shifting DP from scan position 21,13
# Shifting DP from scan position 21,14
# Shifting DP from scan position 21,15
# Shifting DP from scan position 21,16
# Shifting DP from scan position 21,17
# Shifting DP from scan position 21,18
# Shifting DP from scan position 21,19
# Shifting DP from scan position 21,20
# Shifting DP from scan position 21,21
# Shifting DP from scan position 21,22
# Shifting DP from scan position 21,23
# Shifting DP from scan position 21,24
# Shifting DP from scan position 21,25
# Shifting DP from scan position 21,26
# Shifting DP from scan position 21,27
# Shifting DP from scan position 21,28
# Shifting DP from scan position 21,29
# Shifting DP from scan position 21,30
# Shifting DP from scan position 21,31
# Shifting DP from scan position 21,32
# Shifting DP from scan position 21,33
# Shifting DP from scan position 21,34
# Shifting DP from scan position 21,35
# Shifting DP from scan position 21,36
# Shifting DP from scan position 21,37
# Shifting DP from scan position 21,38
# Shifting DP from scan position 21,39
# Shifting DP from scan position 21,40
# Shifting DP from scan position 21,41
# Shifting DP from scan position 21,42
# Shifting DP from scan position 21,43
# Shifting DP from scan position 21,44
# Shifting DP from scan position 21,45
# Shifting DP from scan position 21,46
# Shifting DP from scan position 21,47
# Shifting DP from scan position 21,48
# Shifting DP from scan position 21,49
# Shifting DP from scan position 21,50
# Shifting DP from scan position 21,51
# Shifting DP from scan position 21,52
# Shifting DP from scan position 21,53
# Shifting DP from scan position 21,54
# Shifting DP from scan position 21,55
# Shifting DP from scan position 21,56
# Shifting DP from scan position 21,57
# Shifting DP from scan position 21,58
# ...
# Shifting DP from scan position 52,47
# Shifting DP from scan position 52,48
# Shifting DP from scan position 52,49
# Shifting DP from scan position 52,50
# Shifting DP from scan position 52,51
# Shifting DP from scan position 52,52
# Shifting DP from scan position 52,53
# Shifting DP from scan position 52,54
# Shifting DP from scan position 52,55
# Shifting DP from scan position 52,56
# Shifting DP from scan position 52,57
# Shifting DP from scan position 52,58
# Shifting DP from scan position 52,59
# Shifting DP from scan position 53,0
# Shifting DP from scan position 53,1
# Shifting DP from scan position 53,2
# Shifting DP from scan position 53,3
# Shifting DP from scan position 53,4
# Shifting DP from scan position 53,5
# Shifting DP from scan position 53,6
# Shifting DP from scan position 53,7
# Shifting DP from scan position 53,8
# Shifting DP from scan position 53,9
# Shifting DP from scan position 53,10
# Shifting DP from scan position 53,11
# Shifting DP from scan position 53,12
# Shifting DP from scan position 53,13
# Shifting DP from scan position 53,14
# Shifting DP from scan position 53,15
# Shifting DP from scan position 53,16
# Shifting DP from scan position 53,17
# Shifting DP from scan position 53,18
# Shifting DP from scan position 53,19
# Shifting DP from scan position 53,20
# Shifting DP from scan position 53,21
# Shifting DP from scan position 53,22
# Shifting DP from scan position 53,23
# Shifting DP from scan position 53,24
# Shifting DP from scan position 53,25
# Shifting DP from scan position 53,26
# Shifting DP from scan position 53,27
# Shifting DP from scan position 53,28
# Shifting DP from scan position 53,29
# Shifting DP from scan position 53,30
# Shifting DP from scan position 53,31
# Shifting DP from scan position 53,32
# Shifting DP from scan position 53,33
# Shifting DP from scan position 53,34
# Shifting DP from scan position 53,35
# Shifting DP from scan position 53,36
# Shifting DP from scan position 53,37
# Shifting DP from scan position 53,38
# Shifting DP from scan position 53,39
# Shifting DP from scan position 53,40
# Shifting DP from scan position 53,41
# Shifting DP from scan position 53,42
# Shifting DP from scan position 53,43
# Shifting DP from scan position 53,44
# Shifting DP from scan position 53,45
# Shifting DP from scan position 53,46
# Shifting DP from scan position 53,47
# Shifting DP from scan position 53,48
# Shifting DP from scan position 53,49
# Shifting DP from scan position 53,50
# Shifting DP from scan position 53,51
# Shifting DP from scan position 53,52
# Shifting DP from scan position 53,53
# Shifting DP from scan position 53,54
# Shifting DP from scan position 53,55
# Shifting DP from scan position 53,56
# Shifting DP from scan position 53,57
# Shifting DP from scan position 53,58
# Shifting DP from scan position 53,59
# Shifting DP from scan position 54,0
# Shifting DP from scan position 54,1
# Shifting DP from scan position 54,2
# Shifting DP from scan position 54,3
# Shifting DP from scan position 54,4
# Shifting DP from scan position 54,5
# Shifting DP from scan position 54,6
# Shifting DP from scan position 54,7
# Shifting DP from scan position 54,8
# Shifting DP from scan position 54,9
# Shifting DP from scan position 54,10
# Shifting DP from scan position 54,11
# Shifting DP from scan position 54,12
# Shifting DP from scan position 54,13
# Shifting DP from scan position 54,14
# Shifting DP from scan position 54,15
# Shifting DP from scan position 54,16
# Shifting DP from scan position 54,17
# Shifting DP from scan position 54,18
# Shifting DP from scan position 54,19
# Shifting DP from scan position 54,20
# Shifting DP from scan position 54,21
# Shifting DP from scan position 54,22
# Shifting DP from scan position 54,23
# Shifting DP from scan position 54,24
# Shifting DP from scan position 54,25
# Shifting DP from scan position 54,26
# Shifting DP from scan position 54,27
# Shifting DP from scan position 54,28
# Shifting DP from scan position 54,29
# Shifting DP from scan position 54,30
# Shifting DP from scan position 54,31
# Shifting DP from scan position 54,32
# Shifting DP from scan position 54,33
# Shifting DP from scan position 54,34
# Shifting DP from scan position 54,35
# Shifting DP from scan position 54,36
# Shifting DP from scan position 54,37
# Shifting DP from scan position 54,38
# Shifting DP from scan position 54,39
# Shifting DP from scan position 54,40
# Shifting DP from scan position 54,41
# Shifting DP from scan position 54,42
# Shifting DP from scan position 54,43
# Shifting DP from scan position 54,44
# Shifting DP from scan position 54,45
# Shifting DP from scan position 54,46
# Shifting DP from scan position 54,47
# Shifting DP from scan position 54,48
# Shifting DP from scan position 54,49
# Shifting DP from scan position 54,50
# Shifting DP from scan position 54,51
# Shifting DP from scan position 54,52
# Shifting DP from scan position 54,53
# Shifting DP from scan position 54,54
# Shifting DP from scan position 54,55
# Shifting DP from scan position 54,56
# Shifting DP from scan position 54,57
# Shifting DP from scan position 54,58
# Shifting DP from scan position 54,59
# Shifting DP from scan position 55,0
# Shifting DP from scan position 55,1
# Shifting DP from scan position 55,2
# Shifting DP from scan position 55,3
# Shifting DP from scan position 55,4
# Shifting DP from scan position 55,5
# Shifting DP from scan position 55,6
# Shifting DP from scan position 55,7
# Shifting DP from scan position 55,8
# Shifting DP from scan position 55,9
# Shifting DP from scan position 55,10
# Shifting DP from scan position 55,11
# Shifting DP from scan position 55,12
# Shifting DP from scan position 55,13
# Shifting DP from scan position 55,14
# Shifting DP from scan position 55,15
# Shifting DP from scan position 55,16
# Shifting DP from scan position 55,17
# Shifting DP from scan position 55,18
# Shifting DP from scan position 55,19
# Shifting DP from scan position 55,20
# Shifting DP from scan position 55,21
# Shifting DP from scan position 55,22
# Shifting DP from scan position 55,23
# Shifting DP from scan position 55,24
# Shifting DP from scan position 55,25
# Shifting DP from scan position 55,26
# Shifting DP from scan position 55,27
# Shifting DP from scan position 55,28
# Shifting DP from scan position 55,29
# Shifting DP from scan position 55,30
# Shifting DP from scan position 55,31
# Shifting DP from scan position 55,32
# Shifting DP from scan position 55,33
# Shifting DP from scan position 55,34
# Shifting DP from scan position 55,35
# Shifting DP from scan position 55,36
# Shifting DP from scan position 55,37
# Shifting DP from scan position 55,38
# Shifting DP from scan position 55,39
# Shifting DP from scan position 55,40
# Shifting DP from scan position 55,41
# Shifting DP from scan position 55,42
# Shifting DP from scan position 55,43
# Shifting DP from scan position 55,44
# Shifting DP from scan position 55,45
# Shifting DP from scan position 55,46
# Shifting DP from scan position 55,47
# Shifting DP from scan position 55,48
# Shifting DP from scan position 55,49
# Shifting DP from scan position 55,50
# Shifting DP from scan position 55,51
# Shifting DP from scan position 55,52
# Shifting DP from scan position 55,53
# Shifting DP from scan position 55,54
# Shifting DP from scan position 55,55
# Shifting DP from scan position 55,56
# Shifting DP from scan position 55,57
# Shifting DP from scan position 55,58
# Shifting DP from scan position 55,59
# Shifting DP from scan position 56,0
# Shifting DP from scan position 56,1
# Shifting DP from scan position 56,2
# Shifting DP from scan position 56,3
# Shifting DP from scan position 56,4
# Shifting DP from scan position 56,5
# Shifting DP from scan position 56,6
# Shifting DP from scan position 56,7
# Shifting DP from scan position 56,8
# Shifting DP from scan position 56,9
# Shifting DP from scan position 56,10
# Shifting DP from scan position 56,11
# Shifting DP from scan position 56,12
# Shifting DP from scan position 56,13
# Shifting DP from scan position 56,14
# Shifting DP from scan position 56,15
# Shifting DP from scan position 56,16
# Shifting DP from scan position 56,17
# Shifting DP from scan position 56,18
# Shifting DP from scan position 56,19
# Shifting DP from scan position 56,20
# Shifting DP from scan position 56,21
# Shifting DP from scan position 56,22
# Shifting DP from scan position 56,23
# Shifting DP from scan position 56,24
# Shifting DP from scan position 56,25
# Shifting DP from scan position 56,26
# Shifting DP from scan position 56,27
# Shifting DP from scan position 56,28
# Shifting DP from scan position 56,29
# Shifting DP from scan position 56,30
# Shifting DP from scan position 56,31
# Shifting DP from scan position 56,32
# Shifting DP from scan position 56,33
# Shifting DP from scan position 56,34
# Shifting DP from scan position 56,35
# Shifting DP from scan position 56,36
# Shifting DP from scan position 56,37
# Shifting DP from scan position 56,38
# Shifting DP from scan position 56,39
# Shifting DP from scan position 56,40
# Shifting DP from scan position 56,41
# Shifting DP from scan position 56,42
# Shifting DP from scan position 56,43
# Shifting DP from scan position 56,44
# Shifting DP from scan position 56,45
# Shifting DP from scan position 56,46
# Shifting DP from scan position 56,47
# Shifting DP from scan position 56,48
# Shifting DP from scan position 56,49
# Shifting DP from scan position 56,50
# Shifting DP from scan position 56,51
# Shifting DP from scan position 56,52
# Shifting DP from scan position 56,53
# Shifting DP from scan position 56,54
# Shifting DP from scan position 56,55
# Shifting DP from scan position 56,56
# Shifting DP from scan position 56,57
# Shifting DP from scan position 56,58
# Shifting DP from scan position 56,59
# Shifting DP from scan position 57,0
# Shifting DP from scan position 57,1
# Shifting DP from scan position 57,2
# Shifting DP from scan position 57,3
# Shifting DP from scan position 57,4
# Shifting DP from scan position 57,5
# Shifting DP from scan position 57,6
# Shifting DP from scan position 57,7
# Shifting DP from scan position 57,8
# Shifting DP from scan position 57,9
# Shifting DP from scan position 57,10
# Shifting DP from scan position 57,11
# Shifting DP from scan position 57,12
# Shifting DP from scan position 57,13
# Shifting DP from scan position 57,14
# Shifting DP from scan position 57,15
# Shifting DP from scan position 57,16
# Shifting DP from scan position 57,17
# Shifting DP from scan position 57,18
# Shifting DP from scan position 57,19
# Shifting DP from scan position 57,20
# Shifting DP from scan position 57,21
# Shifting DP from scan position 57,22
# Shifting DP from scan position 57,23
# Shifting DP from scan position 57,24
# Shifting DP from scan position 57,25
# Shifting DP from scan position 57,26
# Shifting DP from scan position 57,27
# Shifting DP from scan position 57,28
# Shifting DP from scan position 57,29
# Shifting DP from scan position 57,30
# Shifting DP from scan position 57,31
# Shifting DP from scan position 57,32
# Shifting DP from scan position 57,33
# Shifting DP from scan position 57,34
# Shifting DP from scan position 57,35
# Shifting DP from scan position 57,36
# Shifting DP from scan position 57,37
# Shifting DP from scan position 57,38
# Shifting DP from scan position 57,39
# Shifting DP from scan position 57,40
# Shifting DP from scan position 57,41
# Shifting DP from scan position 57,42
# Shifting DP from scan position 57,43
# Shifting DP from scan position 57,44
# Shifting DP from scan position 57,45
# Shifting DP from scan position 57,46
# Shifting DP from scan position 57,47
# Shifting DP from scan position 57,48
# Shifting DP from scan position 57,49
# Shifting DP from scan position 57,50
# Shifting DP from scan position 57,51
# Shifting DP from scan position 57,52
# Shifting DP from scan position 57,53
# Shifting DP from scan position 57,54
# Shifting DP from scan position 57,55
# Shifting DP from scan position 57,56
# Shifting DP from scan position 57,57
# Shifting DP from scan position 57,58
# Shifting DP from scan position 57,59
# Shifting DP from scan position 58,0
# Shifting DP from scan position 58,1
# Shifting DP from scan position 58,2
# Shifting DP from scan position 58,3
# Shifting DP from scan position 58,4
# Shifting DP from scan position 58,5
# Shifting DP from scan position 58,6
# Shifting DP from scan position 58,7
# Shifting DP from scan position 58,8
# Shifting DP from scan position 58,9
# Shifting DP from scan position 58,10
# Shifting DP from scan position 58,11
# Shifting DP from scan position 58,12
# Shifting DP from scan position 58,13
# Shifting DP from scan position 58,14
# Shifting DP from scan position 58,15
# Shifting DP from scan position 58,16
# Shifting DP from scan position 58,17
# Shifting DP from scan position 58,18
# Shifting DP from scan position 58,19
# Shifting DP from scan position 58,20
# Shifting DP from scan position 58,21
# Shifting DP from scan position 58,22
# Shifting DP from scan position 58,23
# Shifting DP from scan position 58,24
# Shifting DP from scan position 58,25
# Shifting DP from scan position 58,26
# Shifting DP from scan position 58,27
# Shifting DP from scan position 58,28
# Shifting DP from scan position 58,29
# Shifting DP from scan position 58,30
# Shifting DP from scan position 58,31
# Shifting DP from scan position 58,32
# Shifting DP from scan position 58,33
# Shifting DP from scan position 58,34
# Shifting DP from scan position 58,35
# Shifting DP from scan position 58,36
# Shifting DP from scan position 58,37
# Shifting DP from scan position 58,38
# Shifting DP from scan position 58,39
# Shifting DP from scan position 58,40
# Shifting DP from scan position 58,41
# Shifting DP from scan position 58,42
# Shifting DP from scan position 58,43
# Shifting DP from scan position 58,44
# Shifting DP from scan position 58,45
# Shifting DP from scan position 58,46
# Shifting DP from scan position 58,47
# Shifting DP from scan position 58,48
# Shifting DP from scan position 58,49
# Shifting DP from scan position 58,50
# Shifting DP from scan position 58,51
# Shifting DP from scan position 58,52
# Shifting DP from scan position 58,53
# Shifting DP from scan position 58,54
# Shifting DP from scan position 58,55
# Shifting DP from scan position 58,56
# Shifting DP from scan position 58,57
# Shifting DP from scan position 58,58
# Shifting DP from scan position 58,59
# Shifting DP from scan position 59,0
# Shifting DP from scan position 59,1
# Shifting DP from scan position 59,2
# Shifting DP from scan position 59,3
# Shifting DP from scan position 59,4
# Shifting DP from scan position 59,5
# Shifting DP from scan position 59,6
# Shifting DP from scan position 59,7
# Shifting DP from scan position 59,8
# Shifting DP from scan position 59,9
# Shifting DP from scan position 59,10
# Shifting DP from scan position 59,11
# Shifting DP from scan position 59,12
# Shifting DP from scan position 59,13
# Shifting DP from scan position 59,14
# Shifting DP from scan position 59,15
# Shifting DP from scan position 59,16
# Shifting DP from scan position 59,17
# Shifting DP from scan position 59,18
# Shifting DP from scan position 59,19
# Shifting DP from scan position 59,20
# Shifting DP from scan position 59,21
# Shifting DP from scan position 59,22
# Shifting DP from scan position 59,23
# Shifting DP from scan position 59,24
# Shifting DP from scan position 59,25
# Shifting DP from scan position 59,26
# Shifting DP from scan position 59,27
# Shifting DP from scan position 59,28
# Shifting DP from scan position 59,29
# Shifting DP from scan position 59,30
# Shifting DP from scan position 59,31
# Shifting DP from scan position 59,32
# Shifting DP from scan position 59,33
# Shifting DP from scan position 59,34
# Shifting DP from scan position 59,35
# Shifting DP from scan position 59,36
# Shifting DP from scan position 59,37
# Shifting DP from scan position 59,38
# Shifting DP from scan position 59,39
# Shifting DP from scan position 59,40
# Shifting DP from scan position 59,41
# Shifting DP from scan position 59,42
# Shifting DP from scan position 59,43
# Shifting DP from scan position 59,44
# Shifting DP from scan position 59,45
# Shifting DP from scan position 59,46
# Shifting DP from scan position 59,47
# Shifting DP from scan position 59,48
# Shifting DP from scan position 59,49
# Shifting DP from scan position 59,50
# Shifting DP from scan position 59,51
# Shifting DP from scan position 59,52
# Shifting DP from scan position 59,53
# Shifting DP from scan position 59,54
# Shifting DP from scan position 59,55
# Shifting DP from scan position 59,56
# Shifting DP from scan position 59,57
# Shifting DP from scan position 59,58
# Shifting DP from scan position 59,59
# Finished in 0h 2m 28s

# %%
# Save
dc.data4D = data4D_corrected
fp="/Users/Ben/Desktop/example.h5"
py4DSTEM.readwrite.save_from_datacube(dc,fp)
# Out:
# Creating file /Users/Ben/Desktop/example.h5...
# Writing metadata...
# Done.

# %% [markdown]
# ### 3b. Apply diffraction shifts to deconvolution
#
# * Apply shifts to recalculated averaged deconvolution

# %%
# Get the shift corrected, average deconvolution

average_deconvolution_shiftcorrected = np.zeros((dc.Q_Ny,dc.Q_Nx))

for i in range(len(Bragg_peak_point_list)):
    rx = int(Bragg_peak_point_list['rx'][i])
    ry = int(Bragg_peak_point_list['ry'][i])
    shift_qx = int(diffraction_shifts_fit_x[rx,ry])
    shift_qy = int(diffraction_shifts_fit_y[rx,ry])
    qx = int(Bragg_peak_point_list['qx'][i]) - shift_qx
    qy = int(Bragg_peak_point_list['qy'][i]) - shift_qy

    average_deconvolution_shiftcorrected[qx,qy] += Bragg_peak_point_list['intensity'][i]

# %%
# Plot

x0,y0=py4DSTEM.process.utils.get_CoM(average_deconvolution_shiftcorrected)
x0,y0=int(x0),int(y0)
rad=80

fig,((ax11,ax12),(ax21,ax22))=plt.subplots(2,2,figsize=(16,16))
ax11.matshow(average_deconvolution_shiftcorrected)
ax12.matshow(average_deconvolution_shiftcorrected[x0-rad:x0+rad,y0-rad:y0+rad])
ax21.matshow(average_deconvolution_shiftcorrected**0.15,cmap='jet')
ax22.matshow(average_deconvolution_shiftcorrected[x0-rad:x0+rad,y0-rad:y0+rad]**0.15,cmap='jet')
plt.show()

# %%
# Plot with gaussian blur

sigma = 0

x0,y0=py4DSTEM.process.utils.get_CoM(average_deconvolution_shiftcorrected)
x0,y0=int(x0),int(y0)
rad=80

fig,(ax1,ax2)=plt.subplots(1,2,figsize=(16,16))
ax1.matshow(gaussian_filter(average_deconvolution_shiftcorrected,sigma)**0.15,cmap='jet')
ax2.matshow(gaussian_filter(average_deconvolution_shiftcorrected,sigma)[x0-rad:x0+rad,y0-rad:y0+rad]**0.15,cmap='jet')
plt.show()

# %% [markdown]
# ### 3c. Get deconvolutions from image subregions

# %%
# Select ROI

xmin,xmax=21,42
ymin,ymax=15,40

im_ROI_sel = np.average(dc.data4D,axis=(2,3))
im_ROI_sel[xmin:xmax,ymin:ymax] = 0
fig,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(12,8))
ax1.matshow(np.average(dc.data4D,axis=(2,3)),cmap='gray')
ax2.matshow(im_ROI_sel,cmap='gray')
ax3.matshow(np.average(dc.data4D,axis=(2,3))[xmin:xmax,ymin:ymax,],cmap='gray')
plt.show()

# %%
# Get deconvolution in ROI

average_deconvolution_shiftcorrected_ROI_1 = np.zeros((dc.Q_Ny,dc.Q_Nx))

for i in range(len(Bragg_peak_point_list)):
    rx = int(Bragg_peak_point_list['rx'][i])
    ry = int(Bragg_peak_point_list['ry'][i])
    if ((rx in range(xmin,xmax)) and (ry in range(ymin,ymax))):
        shift_qx = int(diffraction_shifts_fit_x[rx,ry])
        shift_qy = int(diffraction_shifts_fit_y[rx,ry])
        qx = int(Bragg_peak_point_list['qx'][i]) - shift_qx
        qy = int(Bragg_peak_point_list['qy'][i]) - shift_qy

        average_deconvolution_shiftcorrected_ROI_1[qx,qy] += Bragg_peak_point_list['intensity'][i]

# %%
# Plot

x0,y0=py4DSTEM.process.utils.get_CoM(average_deconvolution_shiftcorrected_ROI_1)
x0,y0=int(x0),int(y0)
rad=80

fig,(ax1,ax2)=plt.subplots(1,2,figsize=(16,16))
ax1.matshow(average_deconvolution_shiftcorrected_ROI_1**0.15,cmap='jet')
ax2.matshow(average_deconvolution_shiftcorrected_ROI_1[x0-rad:x0+rad,y0-rad:y0+rad]**0.15,cmap='jet')
plt.show()

# %%
# Select ROI

xmin,xmax=0,19
ymin,ymax=35,60

im_ROI_sel = np.average(dc.data4D,axis=(2,3))
im_ROI_sel[xmin:xmax,ymin:ymax] = 0
fig,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(12,8))
ax1.matshow(np.average(dc.data4D,axis=(2,3)),cmap='gray')
ax2.matshow(im_ROI_sel,cmap='gray')
ax3.matshow(np.average(dc.data4D,axis=(2,3))[xmin:xmax,ymin:ymax,],cmap='gray')
plt.show()

# %%
# Get deconvolution in ROI

average_deconvolution_shiftcorrected_ROI_2 = np.zeros((dc.Q_Ny,dc.Q_Nx))

for i in range(len(Bragg_peak_point_list)):
    rx = int(Bragg_peak_point_list['rx'][i])
    ry = int(Bragg_peak_point_list['ry'][i])
    if ((rx in range(xmin,xmax)) and (ry in range(ymin,ymax))):
        shift_qx = int(diffraction_shifts_fit_x[rx,ry])
        shift_qy = int(diffraction_shifts_fit_y[rx,ry])
        qx = int(Bragg_peak_point_list['qx'][i]) - shift_qx
        qy = int(Bragg_peak_point_list['qy'][i]) - shift_qy

        average_deconvolution_shiftcorrected_ROI_2[qx,qy] += Bragg_peak_point_list['intensity'][i]

# %%
# Plot

x0,y0=py4DSTEM.process.utils.get_CoM(average_deconvolution_shiftcorrected_ROI_2)
x0,y0=int(x0),int(y0)
rad=80

fig,(ax1,ax2)=plt.subplots(1,2,figsize=(16,16))
ax1.matshow(average_deconvolution_shiftcorrected_ROI_2**0.15,cmap='jet')
ax2.matshow(average_deconvolution_shiftcorrected_ROI_2[x0-rad:x0+rad,y0-rad:y0+rad]**0.15,cmap='jet')
plt.show()

# %%
# Select ROI

xmin,xmax=44,49
ymin,ymax=27,36

im_ROI_sel = np.average(dc.data4D,axis=(2,3))
im_ROI_sel[xmin:xmax,ymin:ymax] = 0
fig,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(12,8))
ax1.matshow(np.average(dc.data4D,axis=(2,3)),cmap='gray')
ax2.matshow(im_ROI_sel,cmap='gray')
ax3.matshow(np.average(dc.data4D,axis=(2,3))[xmin:xmax,ymin:ymax,],cmap='gray')
plt.show()

# %%
# Get deconvolution in ROI

average_deconvolution_shiftcorrected_ROI_3 = np.zeros((dc.Q_Ny,dc.Q_Nx))

for i in range(len(Bragg_peak_point_list)):
    rx = int(Bragg_peak_point_list['rx'][i])
    ry = int(Bragg_peak_point_list['ry'][i])
    if ((rx in range(xmin,xmax)) and (ry in range(ymin,ymax))):
        shift_qx = int(diffraction_shifts_fit_x[rx,ry])
        shift_qy = int(diffraction_shifts_fit_y[rx,ry])
        qx = int(Bragg_peak_point_list['qx'][i]) - shift_qx
        qy = int(Bragg_peak_point_list['qy'][i]) - shift_qy

        average_deconvolution_shiftcorrected_ROI_3[qx,qy] += Bragg_peak_point_list['intensity'][i]

# %%
# Plot

x0,y0=py4DSTEM.process.utils.get_CoM(average_deconvolution_shiftcorrected_ROI_3)
x0,y0=int(x0),int(y0)
rad=80

fig,(ax1,ax2)=plt.subplots(1,2,figsize=(16,16))
ax1.matshow(average_deconvolution_shiftcorrected_ROI_3**0.15,cmap='jet')
ax2.matshow(average_deconvolution_shiftcorrected_ROI_3[x0-rad:x0+rad,y0-rad:y0+rad]**0.15,cmap='jet')
plt.show()
